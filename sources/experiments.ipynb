# %%
# Please specify the path to the corpus file downloaded from the link below
# https://lang.org.ua/en/ubertext/
corpus_path = '/Users/horielov.d/Downloads/ubertext-cleaned.txt'

# The total number of news in the Uber Text 2.0 News Cleaned corpus at the time of download
total_news_count = 14232850

# Optional step to calculate the number of news in the corpus for the percentage calculation
# from helpers.read_news_stream import read_news_stream
# 
# total_news_count = 0
# for news_text in read_news_stream(corpus_path):
#     total_news_count += 1

# %% [markdown]
# # 4.2 Phone Number Normalization Results
# ## 4.2.1 Methodology

# %%
import re
from sources.normalizers.ukrainian_phone_normalizer import UkrainianPhoneNormalizer
from sources.helpers.read_news_stream import read_news_stream
from helpers.format_phone_number import format_phone_number

stats_before_normalization = {}
stats_after_normalization = {}
current_news_number = 0
progress_step = 100_000

def calculate_different_phone_numbers_format(news_text: str):
    normalized_line = news_text
    
    for pattern in UkrainianPhoneNormalizer.REGULAR_PHONE_PATTERNS:
        def replace(match):
            if UkrainianPhoneNormalizer.should_not_match(normalized_line, match):
                return match.group(0)

            formatted_phone = format_phone_number(match.group(0))
            stats_before_normalization[formatted_phone] = stats_before_normalization.get(formatted_phone, 0) + 1

            result = UkrainianPhoneNormalizer.format_regular_phone_number(match)

            formatted_result = format_phone_number(result)

            stats_after_normalization[formatted_result] = stats_after_normalization.get(formatted_result, 0) + 1

            return result

        normalized_line = re.sub(pattern, replace, normalized_line)

    for pattern in UkrainianPhoneNormalizer.SPECIAL_PHONE_PATTERNS:
        def replace(match):
            if UkrainianPhoneNormalizer.should_not_match(normalized_line, match):
                return match.group(0)

            formatted_phone = format_phone_number(match.group(0))
            stats_before_normalization[formatted_phone] = stats_before_normalization.get(formatted_phone, 0) + 1

            result = UkrainianPhoneNormalizer.format_special_phone_number(match)

            formatted_result = format_phone_number(result)

            stats_after_normalization[formatted_result] = stats_after_normalization.get(formatted_result, 0) + 1

            return result

        normalized_line = re.sub(pattern, replace, normalized_line)

for news_text in read_news_stream(corpus_path):
    current_news_number += 1
    calculate_different_phone_numbers_format(news_text)
    
    if current_news_number % progress_step == 0:
        print("Current stats:")
        for phone_format, count in sorted(stats_before_normalization.items(), key=lambda x: x[1], reverse=True)[:10]:
            print(f'{phone_format}: {count}')
        
        print(f'\nProcessed ({current_news_number / total_news_count * 100:.2f}%) \n')
# Out:
# Current stats:
# (0XX) XXX-XX-XX: 23
# (0XX) XXX XXXX: 12
# 0XX-XXX-XX-XX: 10
# (0XX) XXX XX XX: 8
# 0XX XXX XX XX: 6
# 0XX-XX-XXX-XX: 4
# (0XXX)XX-XX-XX: 4
# (0XXX) XX-XX-XX: 3
# (0XX)XXX XXXX: 3
# +38 0XX XXX XX XX: 2
#
# Processed (0.70%)
# Current stats:
# (0XX) XXX-XX-XX: 33
# 0XX-XXX-XX-XX: 20
# (0XX) XXX XXXX: 13
# (0XX) XXX XX XX: 12
# 0XX XXX XX XX: 8
# +38 (0XX) XXX-XX-XX: 6
# +38 0XX XXX XX XX: 5
# 0XXXXXXXXX: 5
# 0XX-XX-XXX-XX: 4
# (0XXX)XX-XX-XX: 4
#
# Processed (1.41%)
# Current stats:
# (0XX) XXX-XX-XX: 63
# 0XX-XXX-XX-XX: 21
# (0XX)XXXXXXX: 14
# (0XX) XXX XX XX: 13
# (0XX) XXX XXXX: 13
# (0XXX) XX-XX-XX: 11
# 0XX XXX XX XX: 9
# +38 0XX XXX XX XX: 8
# (0XX)XXX-XX-XX: 8
# (0XXX) XXXXXX: 8
#
# Processed (2.11%)
# Current stats:
# (0XX) XXX-XX-XX: 70
# 0XX-XXX-XX-XX: 21
# (0XX)XXXXXXX: 14
# (0XX) XXX XX XX: 13
# (0XX) XXX XXXX: 13
# (0XXX) XX-XX-XX: 11
# +38 0XX XXX XX XX: 9
# 0XX XXX XX XX: 9
# (0XX)XXX-XX-XX: 8
# (0XXX) XXXXXX: 8
#
# Processed (2.81%)
# Current stats:
# (0XX) XXX-XX-XX: 87
# 0XX-XXX-XX-XX: 23
# (0XX) XXX XX XX: 17
# (0XX)XXXXXXX: 14
# (0XX) XXX XXXX: 13
# (0XXX) XX-XX-XX: 11
# +38 0XX XXX XX XX: 10
# 0XX XXX XX XX: 9
# +380 (XXX) XX-XX-XX: 9
# (0XX)XXX-XX-XX: 8
#
# Processed (3.51%)
# Current stats:
# (0XX) XXX-XX-XX: 101
# 0XX-XXX-XX-XX: 24
# (0XX) XXX XX XX: 17
# (0XX)XXXXXXX: 14
# (0XX) XXX XXXX: 13
# (0XXX) XX-XX-XX: 11
# +380 (XXX) XX-XX-XX: 11
# +38 0XX XXX XX XX: 10
# 0XX XXX XX XX: 10
# (0XX)XXX-XX-XX: 8
#
# Processed (4.22%)
# Current stats:
# (0XX) XXX-XX-XX: 105
# 0XX-XXX-XX-XX: 35
# (0XX) XXX XX XX: 20
# (0XXX) XX-XX-XX: 14
# +380 (XXX) XX-XX-XX: 14
# (0XX)XXXXXXX: 14
# (0XX) XXX XXXX: 13
# +38 0XX XXX XX XX: 10
# 0XX XXX XX XX: 10
# 0 XXX XXX XXX: 8
#
# Processed (4.92%)
# Current stats:
# (0XX) XXX-XX-XX: 119
# 0XX-XXX-XX-XX: 37
# (0XX) XXX XX XX: 20
# +380 (XXX) XX-XX-XX: 17
# (0XXX) XX-XX-XX: 14
# (0XX)XXXXXXX: 14
# (0XX) XXX XXXX: 13
# +38 0XX XXX XX XX: 12
# 0XX XXX XX XX: 12
# 0 XXX XXX XXX: 11
#
# Processed (5.62%)
# Current stats:
# (0XX) XXX-XX-XX: 128
# 0XX-XXX-XX-XX: 41
# (0XX) XXX XX XX: 27
# +380 (XXX) XX-XX-XX: 21
# 0XX XXX XX XX: 18
# (0XXX) XX-XX-XX: 15
# +38 0XX XXX XX XX: 14
# (0XX)XXXXXXX: 14
# (0XX) XXX XXXX: 13
# 0XXXXXXXXX: 12
#
# Processed (6.32%)
# Current stats:
# (0XX) XXX-XX-XX: 149
# 0XX-XXX-XX-XX: 44
# (0XX) XXX XX XX: 31
# 0XX XXX XX XX: 22
# +380 (XXX) XX-XX-XX: 22
# +38 0XX XXX XX XX: 18
# (0XXX) XX-XX-XX: 17
# (0XX)XXXXXXX: 14
# 0XXXXXXXXX: 13
# (0XX) XXX XXXX: 13
#
# Processed (7.03%)
# Current stats:
# (0XX) XXX-XX-XX: 194
# 0XX-XXX-XX-XX: 87
# 0XX XXX XX XX: 44
# 0XXXXXXXXX: 38
# (0XX) XXX XX XX: 37
# +380 (XXX) XX-XX-XX: 36
# +38 0XX XXX XX XX: 25
# (0XXX) XX-XX-XX: 20
# (0XX) XXX XXXX: 16
# 0 XXX XXX XXX: 16
#
# Processed (7.73%)
# Current stats:
# (0XX) XXX-XX-XX: 227
# 0XX-XXX-XX-XX: 108
# 0XX XXX XX XX: 52
# 0XXXXXXXXX: 46
# +380 (XXX) XX-XX-XX: 45
# (0XX) XXX XX XX: 41
# +38 0XX XXX XX XX: 26
# (0XXX) XX-XX-XX: 25
# 0 XXX XXX XXX: 20
# (0XX)XXXXXXX: 18
#
# Processed (8.43%)
# Current stats:
# (0XX) XXX-XX-XX: 244
# 0XX-XXX-XX-XX: 119
# 0XX XXX XX XX: 62
# 0XXXXXXXXX: 59
# +380 (XXX) XX-XX-XX: 54
# (0XX) XXX XX XX: 47
# +38 0XX XXX XX XX: 30
# (0XXX) XX-XX-XX: 30
# 0 XXX XXX XXX: 23
# (0XX)XXXXXXX: 18
#
# Processed (9.13%)
# Current stats:
# (0XX) XXX-XX-XX: 250
# 0XX-XXX-XX-XX: 123
# 0XX XXX XX XX: 66
# +38 0XX XXX XX XX: 62
# +380 (XXX) XX-XX-XX: 61
# 0XXXXXXXXX: 59
# (0XX) XXX XX XX: 55
# (0XXX) XX-XX-XX: 32
# +38 (0XX) XXX-XX-XX: 27
# 0 XXX XXX XXX: 25
#
# Processed (9.84%)
# Current stats:
# (0XX) XXX-XX-XX: 264
# 0XX-XXX-XX-XX: 126
# +380 (XXX) XX-XX-XX: 72
# 0XX XXX XX XX: 68
# +38 0XX XXX XX XX: 66
# (0XX) XXX XX XX: 61
# 0XXXXXXXXX: 61
# (0XXX) XX-XX-XX: 32
# 0 XXX XXX XXX: 29
# +38 (0XX) XXX-XX-XX: 28
#
# Processed (10.54%)
# Current stats:
# (0XX) XXX-XX-XX: 268
# 0XX-XXX-XX-XX: 134
# 0XX XXX XX XX: 73
# +380 (XXX) XX-XX-XX: 73
# (0XX) XXX XX XX: 68
# +38 0XX XXX XX XX: 66
# 0XXXXXXXXX: 64
# (0XXX) XX-XX-XX: 32
# 0 XXX XXX XXX: 30
# +38 (0XX) XXX-XX-XX: 28
#
# Processed (11.24%)
# Current stats:
# (0XX) XXX-XX-XX: 278
# 0XX-XXX-XX-XX: 143
# +380 (XXX) XX-XX-XX: 82
# 0XX XXX XX XX: 76
# +38 0XX XXX XX XX: 70
# (0XX) XXX XX XX: 70
# 0XXXXXXXXX: 70
# (0XXX) XX-XX-XX: 38
# 0 XXX XXX XXX: 33
# +38 (0XX) XXX-XX-XX: 28
#
# Processed (11.94%)
# Current stats:
# (0XX) XXX-XX-XX: 296
# 0XX-XXX-XX-XX: 149
# +380 (XXX) XX-XX-XX: 89
# 0XX XXX XX XX: 77
# +38 0XX XXX XX XX: 75
# 0XXXXXXXXX: 72
# (0XX) XXX XX XX: 71
# (0XXX) XX-XX-XX: 38
# 0 XXX XXX XXX: 36
# 0-XXX-XXX-XXX: 30
#
# Processed (12.65%)
# Current stats:
# (0XX) XXX-XX-XX: 304
# 0XX-XXX-XX-XX: 153
# +380 (XXX) XX-XX-XX: 96
# +38 0XX XXX XX XX: 77
# 0XX XXX XX XX: 77
# 0XXXXXXXXX: 75
# (0XX) XXX XX XX: 72
# (0XXX) XX-XX-XX: 39
# 0 XXX XXX XXX: 38
# 0-XXX-XXX-XXX: 32
#
# Processed (13.35%)
# Current stats:
# (0XX) XXX-XX-XX: 332
# 0XX-XXX-XX-XX: 155
# +380 (XXX) XX-XX-XX: 100
# +38 0XX XXX XX XX: 81
# 0XX XXX XX XX: 81
# 0XXXXXXXXX: 78
# (0XX) XXX XX XX: 72
# 0 XXX XXX XXX: 41
# (0XXX) XX-XX-XX: 39
# 0-XXX-XXX-XXX: 32
#
# Processed (14.05%)
# Current stats:
# (0XX) XXX-XX-XX: 338
# 0XX-XXX-XX-XX: 158
# +380 (XXX) XX-XX-XX: 100
# +38 0XX XXX XX XX: 86
# 0XX XXX XX XX: 82
# 0XXXXXXXXX: 79
# (0XX) XXX XX XX: 72
# 0 XXX XXX XXX: 41
# (0XXX) XX-XX-XX: 39
# 0-XXX-XXX-XXX: 32
#
# Processed (14.75%)
# Current stats:
# (0XX) XXX-XX-XX: 340
# 0XX-XXX-XX-XX: 165
# +380 (XXX) XX-XX-XX: 103
# +38 0XX XXX XX XX: 88
# 0XX XXX XX XX: 83
# 0XXXXXXXXX: 80
# (0XX) XXX XX XX: 72
# 0 XXX XXX XXX: 43
# (0XXX) XX-XX-XX: 39
# +38 (0XX) XXX-XX-XX: 32
#
# Processed (15.46%)
# Current stats:
# (0XX) XXX-XX-XX: 349
# 0XX-XXX-XX-XX: 166
# +380 (XXX) XX-XX-XX: 110
# +38 0XX XXX XX XX: 90
# 0XX XXX XX XX: 84
# 0XXXXXXXXX: 81
# (0XX) XXX XX XX: 73
# 0 XXX XXX XXX: 48
# (0XXX) XX-XX-XX: 40
# 0-XXX-XXX-XXX: 33
#
# Processed (16.16%)
# Current stats:
# (0XX) XXX-XX-XX: 354
# 0XX-XXX-XX-XX: 168
# +380 (XXX) XX-XX-XX: 113
# +38 0XX XXX XX XX: 92
# 0XX XXX XX XX: 88
# 0XXXXXXXXX: 81
# (0XX) XXX XX XX: 75
# 0 XXX XXX XXX: 49
# (0XXX) XX-XX-XX: 40
# 0-XXX-XXX-XXX: 35
#
# Processed (16.86%)
# Current stats:
# (0XX) XXX-XX-XX: 363
# 0XX-XXX-XX-XX: 171
# +380 (XXX) XX-XX-XX: 114
# +38 0XX XXX XX XX: 96
# 0XX XXX XX XX: 93
# 0XXXXXXXXX: 85
# (0XX) XXX XX XX: 78
# 0 XXX XXX XXX: 50
# (0XXX) XX-XX-XX: 40
# 0-XXX-XXX-XXX: 35
#
# Processed (17.56%)
# Current stats:
# (0XX) XXX-XX-XX: 377
# 0XX-XXX-XX-XX: 172
# +380 (XXX) XX-XX-XX: 117
# +38 0XX XXX XX XX: 105
# 0XX XXX XX XX: 94
# 0XXXXXXXXX: 85
# (0XX) XXX XX XX: 80
# 0 XXX XXX XXX: 52
# (0XXX) XX-XX-XX: 40
# +38 (0XX) XXX-XX-XX: 39
#
# Processed (18.27%)
# Current stats:
# (0XX) XXX-XX-XX: 389
# 0XX-XXX-XX-XX: 178
# +380 (XXX) XX-XX-XX: 125
# +38 0XX XXX XX XX: 113
# 0XX XXX XX XX: 95
# 0XXXXXXXXX: 94
# (0XX) XXX XX XX: 80
# 0 XXX XXX XXX: 54
# (0XXX) XX-XX-XX: 47
# +38 (0XX) XXX-XX-XX: 40
#
# Processed (18.97%)
# Current stats:
# (0XX) XXX-XX-XX: 397
# 0XX-XXX-XX-XX: 183
# +380 (XXX) XX-XX-XX: 130
# +38 0XX XXX XX XX: 119
# 0XX XXX XX XX: 99
# 0XXXXXXXXX: 97
# (0XX) XXX XX XX: 81
# 0 XXX XXX XXX: 58
# (0XXX) XX-XX-XX: 47
# +38 (0XX) XXX-XX-XX: 41
#
# Processed (19.67%)
# Current stats:
# (0XX) XXX-XX-XX: 406
# 0XX-XXX-XX-XX: 183
# +380 (XXX) XX-XX-XX: 138
# +38 0XX XXX XX XX: 120
# 0XXXXXXXXX: 108
# 0XX XXX XX XX: 104
# (0XX) XXX XX XX: 82
# 0 XXX XXX XXX: 61
# (0XXX) XX-XX-XX: 47
# +38 (0XX) XXX-XX-XX: 41
#
# Processed (20.38%)
# Current stats:
# (0XX) XXX-XX-XX: 437
# 0XX-XXX-XX-XX: 204
# +380 (XXX) XX-XX-XX: 153
# 0XX XXX XX XX: 130
# +38 0XX XXX XX XX: 122
# 0XXXXXXXXX: 117
# (0XX) XXX XX XX: 101
# 0 XXX XXX XXX: 70
# (0XXX) XX-XX-XX: 63
# 0-XXX-XXX-XXX: 45
#
# Processed (21.08%)
# Current stats:
# (0XX) XXX-XX-XX: 557
# 0XX-XXX-XX-XX: 237
# 0XX XXX XX XX: 183
# +380 (XXX) XX-XX-XX: 175
# 0XXXXXXXXX: 160
# +38 0XX XXX XX XX: 144
# (0XX) XXX XX XX: 116
# 0 XXX XXX XXX: 84
# (0XXX) XX-XX-XX: 63
# +38 (0XX) XXX-XX-XX: 51
#
# Processed (21.78%)
# Current stats:
# (0XX) XXX-XX-XX: 604
# 0XX-XXX-XX-XX: 246
# +380 (XXX) XX-XX-XX: 215
# 0XX XXX XX XX: 207
# 0XXXXXXXXX: 193
# +38 0XX XXX XX XX: 146
# (0XX) XXX XX XX: 132
# 0 XXX XXX XXX: 117
# (0XXX) XX-XX-XX: 66
# 0-XXX-XXX-XXX: 54
#
# Processed (22.48%)
# Current stats:
# (0XX) XXX-XX-XX: 612
# 0XX-XXX-XX-XX: 252
# 0XX XXX XX XX: 219
# +380 (XXX) XX-XX-XX: 217
# 0XXXXXXXXX: 209
# +38 0XX XXX XX XX: 153
# (0XX) XXX XX XX: 136
# 0 XXX XXX XXX: 118
# (0XXX) XX-XX-XX: 66
# 0-XXX-XXX-XXX: 55
#
# Processed (23.19%)
# Current stats:
# (0XX) XXX-XX-XX: 622
# 0XX-XXX-XX-XX: 264
# 0XX XXX XX XX: 236
# +380 (XXX) XX-XX-XX: 228
# 0XXXXXXXXX: 218
# +38 0XX XXX XX XX: 177
# (0XX) XXX XX XX: 155
# 0 XXX XXX XXX: 126
# (0XXX) XX-XX-XX: 66
# 0-XXX-XXX-XXX: 55
#
# Processed (23.89%)
# Current stats:
# (0XX) XXX-XX-XX: 635
# 0XX-XXX-XX-XX: 267
# 0XX XXX XX XX: 244
# 0XXXXXXXXX: 234
# +380 (XXX) XX-XX-XX: 234
# +38 0XX XXX XX XX: 179
# (0XX) XXX XX XX: 158
# 0 XXX XXX XXX: 130
# +38 (0XX) XXX-XX-XX: 67
# (0XXX) XX-XX-XX: 66
#
# Processed (24.59%)
# Current stats:
# (0XX) XXX-XX-XX: 673
# 0XX-XXX-XX-XX: 296
# 0XX XXX XX XX: 285
# 0XXXXXXXXX: 272
# +380 (XXX) XX-XX-XX: 236
# +38 0XX XXX XX XX: 182
# (0XX) XXX XX XX: 174
# 0 XXX XXX XXX: 130
# +38 (0XX) XXX-XX-XX: 76
# (0XXX) XX-XX-XX: 66
#
# Processed (25.29%)
# Current stats:
# (0XX) XXX-XX-XX: 705
# 0XX XXX XX XX: 341
# 0XXXXXXXXX: 328
# 0XX-XXX-XX-XX: 324
# +380 (XXX) XX-XX-XX: 252
# +38 0XX XXX XX XX: 205
# (0XX) XXX XX XX: 201
# 0 XXX XXX XXX: 137
# +38 (0XX) XXX-XX-XX: 77
# (0XXX) XX-XX-XX: 69
#
# Processed (26.00%)
# Current stats:
# (0XX) XXX-XX-XX: 779
# 0XX XXX XX XX: 370
# 0XX-XXX-XX-XX: 366
# 0XXXXXXXXX: 358
# +380 (XXX) XX-XX-XX: 264
# +38 0XX XXX XX XX: 241
# (0XX) XXX XX XX: 214
# 0 XXX XXX XXX: 145
# +38 (0XX) XXX-XX-XX: 84
# +380XXXXXXXXX: 76
#
# Processed (26.70%)
# Current stats:
# (0XX) XXX-XX-XX: 913
# 0XX XXX XX XX: 481
# 0XX-XXX-XX-XX: 440
# 0XXXXXXXXX: 417
# (0XX) XXX XX XX: 306
# +380 (XXX) XX-XX-XX: 292
# +38 0XX XXX XX XX: 273
# 0 XXX XXX XXX: 155
# +38 (0XX) XXX-XX-XX: 99
# +380XXXXXXXXX: 92
#
# Processed (27.40%)
# Current stats:
# (0XX) XXX-XX-XX: 952
# 0XX XXX XX XX: 498
# 0XX-XXX-XX-XX: 453
# 0XXXXXXXXX: 436
# (0XX) XXX XX XX: 311
# +380 (XXX) XX-XX-XX: 309
# +38 0XX XXX XX XX: 285
# 0 XXX XXX XXX: 157
# +38 (0XX) XXX-XX-XX: 100
# +380XXXXXXXXX: 96
#
# Processed (28.10%)
# Current stats:
# (0XX) XXX-XX-XX: 960
# 0XX XXX XX XX: 502
# 0XX-XXX-XX-XX: 457
# 0XXXXXXXXX: 444
# (0XX) XXX XX XX: 327
# +380 (XXX) XX-XX-XX: 312
# +38 0XX XXX XX XX: 292
# 0 XXX XXX XXX: 160
# +38 (0XX) XXX-XX-XX: 102
# +380XXXXXXXXX: 99
#
# Processed (28.81%)
# Current stats:
# (0XX) XXX-XX-XX: 1041
# 0XX XXX XX XX: 586
# 0XX-XXX-XX-XX: 501
# 0XXXXXXXXX: 491
# (0XX) XXX XX XX: 368
# +380 (XXX) XX-XX-XX: 330
# +38 0XX XXX XX XX: 311
# 0 XXX XXX XXX: 169
# +380XXXXXXXXX: 105
# +38 (0XX) XXX-XX-XX: 103
#
# Processed (29.51%)
# Current stats:
# (0XX) XXX-XX-XX: 1811
# 0XX XXX XX XX: 841
# 0XX-XXX-XX-XX: 794
# 0XXXXXXXXX: 710
# (0XX) XXX XX XX: 479
# +380 (XXX) XX-XX-XX: 412
# +38 0XX XXX XX XX: 323
# (0XXX) XX-XX-XX: 203
# 0 XXX XXX XXX: 196
# +38 (0XX) XXX XX XX: 149
#
# Processed (30.21%)
# Current stats:
# (0XX) XXX-XX-XX: 2753
# 0XX-XXX-XX-XX: 1300
# 0XX XXX XX XX: 1166
# 0XXXXXXXXX: 872
# (0XX) XXX XX XX: 711
# +380 (XXX) XX-XX-XX: 596
# +38 0XX XXX XX XX: 361
# (0XXX) XX-XX-XX: 303
# +38 (0XX) XXX XX XX: 296
# 0 XXX XXX XXX: 233
#
# Processed (30.91%)
# Current stats:
# (0XX) XXX-XX-XX: 3358
# 0XX-XXX-XX-XX: 1677
# 0XX XXX XX XX: 1400
# 0XXXXXXXXX: 973
# (0XX) XXX XX XX: 848
# +380 (XXX) XX-XX-XX: 710
# +38 0XX XXX XX XX: 382
# (0XXX) XX-XX-XX: 366
# +38 (0XX) XXX XX XX: 331
# 0 XXX XXX XXX: 275
#
# Processed (31.62%)
# Current stats:
# (0XX) XXX-XX-XX: 3621
# 0XX-XXX-XX-XX: 1874
# 0XX XXX XX XX: 1600
# 0XXXXXXXXX: 1214
# (0XX) XXX XX XX: 1193
# +380 (XXX) XX-XX-XX: 752
# +38 0XX XXX XX XX: 431
# (0XXX) XX-XX-XX: 394
# +38 (0XX) XXX XX XX: 342
# (0XXXX) X-XX-XX: 303
#
# Processed (32.32%)
# Current stats:
# (0XX) XXX-XX-XX: 3769
# 0XX-XXX-XX-XX: 2021
# 0XX XXX XX XX: 1731
# 0XXXXXXXXX: 1300
# (0XX) XXX XX XX: 1242
# +380 (XXX) XX-XX-XX: 781
# +38 0XX XXX XX XX: 483
# (0XXX) XX-XX-XX: 397
# +38 (0XX) XXX XX XX: 348
# (0XXXX) X-XX-XX: 316
#
# Processed (33.02%)
# Current stats:
# (0XX) XXX-XX-XX: 5228
# 0XX-XXX-XX-XX: 2171
# 0XX XXX XX XX: 1861
# 0XXXXXXXXX: 1398
# (0XX) XXX XX XX: 1323
# +380 (XXX) XX-XX-XX: 808
# +38 0XX XXX XX XX: 510
# (0XXX) XX-XX-XX: 401
# +38 (0XX) XXX XX XX: 358
# (0XXXX) X-XX-XX: 336
#
# Processed (33.72%)
# Current stats:
# (0XX) XXX-XX-XX: 5283
# 0XX-XXX-XX-XX: 2194
# 0XX XXX XX XX: 1937
# 0XXXXXXXXX: 1429
# (0XX) XXX XX XX: 1333
# +380 (XXX) XX-XX-XX: 825
# +38 0XX XXX XX XX: 518
# (0XXX) XX-XX-XX: 410
# +38 (0XX) XXX XX XX: 362
# (0XXXX) X-XX-XX: 338
#
# Processed (34.43%)
# Current stats:
# (0XX) XXX-XX-XX: 5348
# 0XX-XXX-XX-XX: 2200
# 0XX XXX XX XX: 1938
# 0XXXXXXXXX: 1429
# (0XX) XXX XX XX: 1336
# +380 (XXX) XX-XX-XX: 830
# +38 0XX XXX XX XX: 521
# (0XXX) XX-XX-XX: 426
# +38 (0XX) XXX XX XX: 362
# (0XXXX) X-XX-XX: 341
#
# Processed (35.13%)
# Current stats:
# (0XX) XXX-XX-XX: 5380
# 0XX-XXX-XX-XX: 2210
# 0XX XXX XX XX: 1940
# 0XXXXXXXXX: 1429
# (0XX) XXX XX XX: 1338
# +380 (XXX) XX-XX-XX: 840
# +38 0XX XXX XX XX: 522
# (0XXX) XX-XX-XX: 426
# +38 (0XX) XXX XX XX: 362
# (0XXXX) X-XX-XX: 341
#
# Processed (35.83%)
# Current stats:
# (0XX) XXX-XX-XX: 5381
# 0XX-XXX-XX-XX: 2210
# 0XX XXX XX XX: 1940
# 0XXXXXXXXX: 1429
# (0XX) XXX XX XX: 1338
# +380 (XXX) XX-XX-XX: 840
# +38 0XX XXX XX XX: 526
# (0XXX) XX-XX-XX: 426
# +38 (0XX) XXX XX XX: 364
# (0XXXX) X-XX-XX: 341
#
# Processed (36.54%)
# Current stats:
# (0XX) XXX-XX-XX: 5390
# 0XX-XXX-XX-XX: 2211
# 0XX XXX XX XX: 1944
# 0XXXXXXXXX: 1434
# (0XX) XXX XX XX: 1340
# +380 (XXX) XX-XX-XX: 842
# +38 0XX XXX XX XX: 535
# (0XXX) XX-XX-XX: 426
# +38 (0XX) XXX XX XX: 364
# (0XXXX) X-XX-XX: 341
#
# Processed (37.24%)
# Current stats:
# (0XX) XXX-XX-XX: 5460
# 0XX-XXX-XX-XX: 2239
# 0XX XXX XX XX: 1969
# 0XXXXXXXXX: 1446
# (0XX) XXX XX XX: 1360
# +380 (XXX) XX-XX-XX: 882
# +38 0XX XXX XX XX: 553
# (0XXX) XX-XX-XX: 457
# +38 (0XX) XXX XX XX: 368
# 0 XXX XXX XXX: 342
#
# Processed (37.94%)
# Current stats:
# (0XX) XXX-XX-XX: 5579
# 0XX-XXX-XX-XX: 2273
# 0XX XXX XX XX: 2004
# 0XXXXXXXXX: 1455
# (0XX) XXX XX XX: 1408
# +380 (XXX) XX-XX-XX: 892
# +38 0XX XXX XX XX: 588
# (0XXX) XX-XX-XX: 469
# +38 (0XX) XXX XX XX: 370
# (0XXXX) X-XX-XX: 344
#
# Processed (38.64%)
# Current stats:
# (0XX) XXX-XX-XX: 5634
# 0XX-XXX-XX-XX: 2290
# 0XX XXX XX XX: 2016
# 0XXXXXXXXX: 1467
# (0XX) XXX XX XX: 1423
# +380 (XXX) XX-XX-XX: 896
# +38 0XX XXX XX XX: 594
# (0XXX) XX-XX-XX: 470
# +38 (0XX) XXX XX XX: 374
# 0 XXX XXX XXX: 346
#
# Processed (39.35%)
# Current stats:
# (0XX) XXX-XX-XX: 5645
# 0XX-XXX-XX-XX: 2304
# 0XX XXX XX XX: 2020
# 0XXXXXXXXX: 1468
# (0XX) XXX XX XX: 1442
# +380 (XXX) XX-XX-XX: 908
# +38 0XX XXX XX XX: 596
# (0XXX) XX-XX-XX: 473
# +38 (0XX) XXX XX XX: 375
# 0 XXX XXX XXX: 354
#
# Processed (40.05%)
# Current stats:
# (0XX) XXX-XX-XX: 5900
# 0XX-XXX-XX-XX: 2439
# 0XX XXX XX XX: 2088
# (0XX) XXX XX XX: 1532
# 0XXXXXXXXX: 1491
# +380 (XXX) XX-XX-XX: 919
# +38 0XX XXX XX XX: 612
# (0XXX) XX-XX-XX: 479
# +38 (0XX) XXX XX XX: 379
# (0XX)XXX-XX-XX: 377
#
# Processed (40.75%)
# Current stats:
# (0XX) XXX-XX-XX: 6063
# 0XX-XXX-XX-XX: 2509
# 0XX XXX XX XX: 2106
# (0XX) XXX XX XX: 1562
# 0XXXXXXXXX: 1504
# +380 (XXX) XX-XX-XX: 923
# +38 0XX XXX XX XX: 617
# (0XXX) XX-XX-XX: 480
# (0XX)XXX-XX-XX: 430
# +38 (0XX) XXX XX XX: 383
#
# Processed (41.45%)
# Current stats:
# (0XX) XXX-XX-XX: 6147
# 0XX-XXX-XX-XX: 2617
# 0XX XXX XX XX: 2113
# (0XX) XXX XX XX: 1574
# 0XXXXXXXXX: 1528
# +380 (XXX) XX-XX-XX: 930
# +38 0XX XXX XX XX: 620
# (0XXX) XX-XX-XX: 485
# (0XX)XXX-XX-XX: 438
# +38 (0XX) XXX XX XX: 384
#
# Processed (42.16%)
# Current stats:
# (0XX) XXX-XX-XX: 6241
# 0XX-XXX-XX-XX: 2657
# 0XX XXX XX XX: 2180
# (0XX) XXX XX XX: 1651
# 0XXXXXXXXX: 1610
# +380 (XXX) XX-XX-XX: 937
# +38 0XX XXX XX XX: 649
# (0XXX) XX-XX-XX: 533
# (0XX)XXX-XX-XX: 449
# +38 (0XX) XXX XX XX: 405
#
# Processed (42.86%)
# Current stats:
# (0XX) XXX-XX-XX: 6521
# 0XX-XXX-XX-XX: 2731
# 0XX XXX XX XX: 2186
# 0XXXXXXXXX: 1825
# (0XX) XXX XX XX: 1671
# +380 (XXX) XX-XX-XX: 939
# +38 0XX XXX XX XX: 649
# (0XXX) XX-XX-XX: 547
# (0XX)XXX-XX-XX: 475
# +380XXXXXXXXX: 432
#
# Processed (43.56%)
# Current stats:
# (0XX) XXX-XX-XX: 6575
# 0XX-XXX-XX-XX: 2732
# 0XX XXX XX XX: 2187
# 0XXXXXXXXX: 1827
# (0XX) XXX XX XX: 1673
# +380 (XXX) XX-XX-XX: 943
# +38 0XX XXX XX XX: 650
# (0XXX) XX-XX-XX: 560
# (0XX)XXX-XX-XX: 475
# +380XXXXXXXXX: 443
#
# Processed (44.26%)
# Current stats:
# (0XX) XXX-XX-XX: 6874
# 0XX-XXX-XX-XX: 2959
# 0XX XXX XX XX: 2318
# 0XXXXXXXXX: 2029
# (0XX) XXX XX XX: 1730
# +380 (XXX) XX-XX-XX: 1029
# (0XXX) XX-XX-XX: 826
# +38 0XX XXX XX XX: 676
# (0XX)XXX-XX-XX: 573
# (0XXXX) X-XX-XX: 555
#
# Processed (44.97%)
# Current stats:
# (0XX) XXX-XX-XX: 7101
# 0XX-XXX-XX-XX: 3429
# 0XX XXX XX XX: 2496
# 0XXXXXXXXX: 2183
# (0XX) XXX XX XX: 1789
# +380 (XXX) XX-XX-XX: 1112
# (0XXX) XX-XX-XX: 971
# +38 0XX XXX XX XX: 735
# (0XX)XXX-XX-XX: 629
# (0XXXX) X-XX-XX: 580
#
# Processed (45.67%)
# Current stats:
# (0XX) XXX-XX-XX: 7230
# 0XX-XXX-XX-XX: 3533
# 0XX XXX XX XX: 2881
# 0XXXXXXXXX: 2241
# (0XX) XXX XX XX: 1902
# +380 (XXX) XX-XX-XX: 1142
# (0XXX) XX-XX-XX: 991
# +38 0XX XXX XX XX: 749
# (0XX)XXX-XX-XX: 649
# (0XXXX) X-XX-XX: 581
#
# Processed (46.37%)
# Current stats:
# (0XX) XXX-XX-XX: 7251
# 0XX-XXX-XX-XX: 3542
# 0XX XXX XX XX: 2898
# 0XXXXXXXXX: 2260
# (0XX) XXX XX XX: 1922
# +380 (XXX) XX-XX-XX: 1161
# (0XXX) XX-XX-XX: 991
# +38 0XX XXX XX XX: 752
# (0XX)XXX-XX-XX: 678
# (0XXXX) X-XX-XX: 582
#
# Processed (47.07%)
# Current stats:
# (0XX) XXX-XX-XX: 7262
# 0XX-XXX-XX-XX: 3545
# 0XX XXX XX XX: 2913
# 0XXXXXXXXX: 2268
# (0XX) XXX XX XX: 1959
# +380 (XXX) XX-XX-XX: 1175
# (0XXX) XX-XX-XX: 991
# +38 0XX XXX XX XX: 756
# (0XX)XXX-XX-XX: 719
# (0XXXX) X-XX-XX: 582
#
# Processed (47.78%)
# Current stats:
# (0XX) XXX-XX-XX: 7277
# 0XX-XXX-XX-XX: 3555
# 0XX XXX XX XX: 2930
# 0XXXXXXXXX: 2276
# (0XX) XXX XX XX: 1991
# +380 (XXX) XX-XX-XX: 1179
# (0XXX) XX-XX-XX: 993
# +38 0XX XXX XX XX: 765
# (0XX)XXX-XX-XX: 749
# (0XXXX) X-XX-XX: 582
#
# Processed (48.48%)
# Current stats:
# (0XX) XXX-XX-XX: 7290
# 0XX-XXX-XX-XX: 3562
# 0XX XXX XX XX: 2931
# 0XXXXXXXXX: 2282
# (0XX) XXX XX XX: 2005
# +380 (XXX) XX-XX-XX: 1188
# (0XXX) XX-XX-XX: 994
# (0XX)XXX-XX-XX: 788
# +38 0XX XXX XX XX: 766
# (0XXXX) X-XX-XX: 584
#
# Processed (49.18%)
# Current stats:
# (0XX) XXX-XX-XX: 7303
# 0XX-XXX-XX-XX: 3570
# 0XX XXX XX XX: 2938
# 0XXXXXXXXX: 2295
# (0XX) XXX XX XX: 2039
# +380 (XXX) XX-XX-XX: 1194
# (0XXX) XX-XX-XX: 1000
# (0XX)XXX-XX-XX: 824
# +38 0XX XXX XX XX: 769
# (0XXXX) X-XX-XX: 585
#
# Processed (49.88%)
# Current stats:
# (0XX) XXX-XX-XX: 7318
# 0XX-XXX-XX-XX: 3592
# 0XX XXX XX XX: 2962
# 0XXXXXXXXX: 2308
# (0XX) XXX XX XX: 2087
# +380 (XXX) XX-XX-XX: 1213
# (0XXX) XX-XX-XX: 1000
# (0XX)XXX-XX-XX: 867
# +38 0XX XXX XX XX: 772
# (0XXXX) X-XX-XX: 585
#
# Processed (50.59%)
# Current stats:
# (0XX) XXX-XX-XX: 7340
# 0XX-XXX-XX-XX: 3599
# 0XX XXX XX XX: 3006
# 0XXXXXXXXX: 2315
# (0XX) XXX XX XX: 2088
# +380 (XXX) XX-XX-XX: 1273
# (0XXX) XX-XX-XX: 1004
# (0XX)XXX-XX-XX: 867
# +38 0XX XXX XX XX: 775
# (0XXXX) X-XX-XX: 588
#
# Processed (51.29%)
# Current stats:
# (0XX) XXX-XX-XX: 7341
# 0XX-XXX-XX-XX: 3602
# 0XX XXX XX XX: 3010
# 0XXXXXXXXX: 2315
# (0XX) XXX XX XX: 2090
# +380 (XXX) XX-XX-XX: 1275
# (0XXX) XX-XX-XX: 1005
# (0XX)XXX-XX-XX: 868
# +38 0XX XXX XX XX: 779
# (0XXXX) X-XX-XX: 588
#
# Processed (51.99%)
# Current stats:
# (0XX) XXX-XX-XX: 7346
# 0XX-XXX-XX-XX: 3620
# 0XX XXX XX XX: 3011
# 0XXXXXXXXX: 2322
# (0XX) XXX XX XX: 2093
# +380 (XXX) XX-XX-XX: 1280
# (0XXX) XX-XX-XX: 1005
# (0XX)XXX-XX-XX: 869
# +38 0XX XXX XX XX: 780
# (0XXXX) X-XX-XX: 588
#
# Processed (52.69%)
# Current stats:
# (0XX) XXX-XX-XX: 7407
# 0XX-XXX-XX-XX: 3654
# 0XX XXX XX XX: 3057
# 0XXXXXXXXX: 2346
# (0XX) XXX XX XX: 2107
# +380 (XXX) XX-XX-XX: 1301
# (0XXX) XX-XX-XX: 1007
# (0XX)XXX-XX-XX: 892
# +38 0XX XXX XX XX: 786
# (0XXXX) X-XX-XX: 599
#
# Processed (53.40%)
# Current stats:
# (0XX) XXX-XX-XX: 7548
# 0XX-XXX-XX-XX: 3746
# 0XX XXX XX XX: 3129
# 0XXXXXXXXX: 2382
# (0XX) XXX XX XX: 2119
# +380 (XXX) XX-XX-XX: 1311
# (0XXX) XX-XX-XX: 1008
# (0XX)XXX-XX-XX: 902
# +38 0XX XXX XX XX: 791
# (0XXXX) X-XX-XX: 660
#
# Processed (54.10%)
# Current stats:
# (0XX) XXX-XX-XX: 7577
# 0XX-XXX-XX-XX: 3756
# 0XX XXX XX XX: 3134
# 0XXXXXXXXX: 2384
# (0XX) XXX XX XX: 2122
# +380 (XXX) XX-XX-XX: 1316
# (0XXX) XX-XX-XX: 1008
# (0XX)XXX-XX-XX: 902
# +38 0XX XXX XX XX: 795
# (0XXXX) X-XX-XX: 660
#
# Processed (54.80%)
# Current stats:
# (0XX) XXX-XX-XX: 7586
# 0XX-XXX-XX-XX: 3759
# 0XX XXX XX XX: 3136
# 0XXXXXXXXX: 2384
# (0XX) XXX XX XX: 2122
# +380 (XXX) XX-XX-XX: 1318
# (0XXX) XX-XX-XX: 1009
# (0XX)XXX-XX-XX: 902
# +38 0XX XXX XX XX: 795
# (0XXXX) X-XX-XX: 660
#
# Processed (55.51%)
# Current stats:
# (0XX) XXX-XX-XX: 7587
# 0XX-XXX-XX-XX: 3760
# 0XX XXX XX XX: 3136
# 0XXXXXXXXX: 2384
# (0XX) XXX XX XX: 2136
# +380 (XXX) XX-XX-XX: 1318
# (0XXX) XX-XX-XX: 1009
# (0XX)XXX-XX-XX: 902
# +38 0XX XXX XX XX: 801
# (0XXXX) X-XX-XX: 660
#
# Processed (56.21%)
# Current stats:
# (0XX) XXX-XX-XX: 7591
# 0XX-XXX-XX-XX: 3761
# 0XX XXX XX XX: 3137
# 0XXXXXXXXX: 2387
# (0XX) XXX XX XX: 2136
# +380 (XXX) XX-XX-XX: 1321
# (0XXX) XX-XX-XX: 1009
# (0XX)XXX-XX-XX: 902
# +38 0XX XXX XX XX: 803
# (0XXXX) X-XX-XX: 660
#
# Processed (56.91%)
# Current stats:
# (0XX) XXX-XX-XX: 7596
# 0XX-XXX-XX-XX: 3762
# 0XX XXX XX XX: 3138
# 0XXXXXXXXX: 2389
# (0XX) XXX XX XX: 2138
# +380 (XXX) XX-XX-XX: 1331
# (0XXX) XX-XX-XX: 1010
# (0XX)XXX-XX-XX: 902
# +38 0XX XXX XX XX: 804
# (0XXXX) X-XX-XX: 661
#
# Processed (57.61%)
# Current stats:
# (0XX) XXX-XX-XX: 7609
# 0XX-XXX-XX-XX: 3763
# 0XX XXX XX XX: 3141
# 0XXXXXXXXX: 2392
# (0XX) XXX XX XX: 2138
# +380 (XXX) XX-XX-XX: 1340
# (0XXX) XX-XX-XX: 1010
# (0XX)XXX-XX-XX: 902
# +38 0XX XXX XX XX: 807
# (0XXXX) X-XX-XX: 661
#
# Processed (58.32%)
# Current stats:
# (0XX) XXX-XX-XX: 7613
# 0XX-XXX-XX-XX: 3766
# 0XX XXX XX XX: 3142
# 0XXXXXXXXX: 2393
# (0XX) XXX XX XX: 2141
# +380 (XXX) XX-XX-XX: 1352
# (0XXX) XX-XX-XX: 1010
# (0XX)XXX-XX-XX: 902
# +38 0XX XXX XX XX: 808
# (0XXXX) X-XX-XX: 661
#
# Processed (59.02%)
# Current stats:
# (0XX) XXX-XX-XX: 7650
# 0XX-XXX-XX-XX: 3791
# 0XX XXX XX XX: 3153
# 0XXXXXXXXX: 2406
# (0XX) XXX XX XX: 2155
# +380 (XXX) XX-XX-XX: 1376
# (0XXX) XX-XX-XX: 1015
# (0XX)XXX-XX-XX: 905
# +38 0XX XXX XX XX: 818
# (0XXXX) X-XX-XX: 664
#
# Processed (59.72%)
# Current stats:
# (0XX) XXX-XX-XX: 7659
# 0XX-XXX-XX-XX: 3808
# 0XX XXX XX XX: 3161
# 0XXXXXXXXX: 2411
# (0XX) XXX XX XX: 2160
# +380 (XXX) XX-XX-XX: 1390
# (0XXX) XX-XX-XX: 1016
# (0XX)XXX-XX-XX: 908
# +38 0XX XXX XX XX: 820
# (0XXXX) X-XX-XX: 667
#
# Processed (60.42%)
# Current stats:
# (0XX) XXX-XX-XX: 7660
# 0XX-XXX-XX-XX: 3808
# 0XX XXX XX XX: 3169
# 0XXXXXXXXX: 2413
# (0XX) XXX XX XX: 2162
# +380 (XXX) XX-XX-XX: 1398
# (0XXX) XX-XX-XX: 1016
# (0XX)XXX-XX-XX: 908
# +38 0XX XXX XX XX: 822
# (0XXXX) X-XX-XX: 667
#
# Processed (61.13%)
# Current stats:
# (0XX) XXX-XX-XX: 7691
# 0XX-XXX-XX-XX: 3811
# 0XX XXX XX XX: 3173
# 0XXXXXXXXX: 2421
# (0XX) XXX XX XX: 2163
# +380 (XXX) XX-XX-XX: 1402
# (0XXX) XX-XX-XX: 1021
# (0XX)XXX-XX-XX: 911
# +38 0XX XXX XX XX: 826
# (0XXXX) X-XX-XX: 669
#
# Processed (61.83%)
# Current stats:
# (0XX) XXX-XX-XX: 7800
# 0XX-XXX-XX-XX: 3991
# 0XX XXX XX XX: 3207
# 0XXXXXXXXX: 2476
# (0XX) XXX XX XX: 2181
# +380 (XXX) XX-XX-XX: 1430
# (0XXX) XX-XX-XX: 1166
# (0XX)XXX-XX-XX: 923
# +38 0XX XXX XX XX: 827
# (0XXXX) X-XX-XX: 722
#
# Processed (62.53%)
# Current stats:
# (0XX) XXX-XX-XX: 8010
# 0XX-XXX-XX-XX: 4277
# 0XX XXX XX XX: 3362
# 0XXXXXXXXX: 2694
# (0XX) XXX XX XX: 2235
# (0XXX) XX-XX-XX: 1538
# +380 (XXX) XX-XX-XX: 1469
# (0XX)XXX-XX-XX: 955
# (0XXXX) X-XX-XX: 931
# +38 0XX XXX XX XX: 847
#
# Processed (63.23%)
# Current stats:
# (0XX) XXX-XX-XX: 8065
# 0XX-XXX-XX-XX: 4324
# 0XX XXX XX XX: 3379
# 0XXXXXXXXX: 2737
# (0XX) XXX XX XX: 2241
# (0XXX) XX-XX-XX: 1612
# +380 (XXX) XX-XX-XX: 1488
# (0XXXX) X-XX-XX: 997
# (0XX)XXX-XX-XX: 958
# +38 0XX XXX XX XX: 851
#
# Processed (63.94%)
# Current stats:
# (0XX) XXX-XX-XX: 8078
# 0XX-XXX-XX-XX: 4347
# 0XX XXX XX XX: 3382
# 0XXXXXXXXX: 2755
# (0XX) XXX XX XX: 2248
# (0XXX) XX-XX-XX: 1613
# +380 (XXX) XX-XX-XX: 1492
# (0XXXX) X-XX-XX: 997
# (0XX)XXX-XX-XX: 960
# +38 0XX XXX XX XX: 861
#
# Processed (64.64%)
# Current stats:
# (0XX) XXX-XX-XX: 8103
# 0XX-XXX-XX-XX: 4357
# 0XX XXX XX XX: 3392
# 0XXXXXXXXX: 2758
# (0XX) XXX XX XX: 2249
# (0XXX) XX-XX-XX: 1619
# +380 (XXX) XX-XX-XX: 1503
# (0XXXX) X-XX-XX: 997
# (0XX)XXX-XX-XX: 964
# +38 0XX XXX XX XX: 867
#
# Processed (65.34%)
# Current stats:
# (0XX) XXX-XX-XX: 8115
# 0XX-XXX-XX-XX: 4367
# 0XX XXX XX XX: 3396
# 0XXXXXXXXX: 2758
# (0XX) XXX XX XX: 2258
# (0XXX) XX-XX-XX: 1620
# +380 (XXX) XX-XX-XX: 1504
# (0XXXX) X-XX-XX: 997
# (0XX)XXX-XX-XX: 964
# +38 0XX XXX XX XX: 869
#
# Processed (66.04%)
# Current stats:
# (0XX) XXX-XX-XX: 8116
# 0XX-XXX-XX-XX: 4374
# 0XX XXX XX XX: 3400
# 0XXXXXXXXX: 2760
# (0XX) XXX XX XX: 2268
# (0XXX) XX-XX-XX: 1621
# +380 (XXX) XX-XX-XX: 1516
# (0XXXX) X-XX-XX: 998
# (0XX)XXX-XX-XX: 969
# +38 0XX XXX XX XX: 871
#
# Processed (66.75%)
# Current stats:
# (0XX) XXX-XX-XX: 8180
# 0XX-XXX-XX-XX: 4407
# 0XX XXX XX XX: 3412
# 0XXXXXXXXX: 2771
# (0XX) XXX XX XX: 2328
# (0XXX) XX-XX-XX: 1627
# +380 (XXX) XX-XX-XX: 1553
# (0XXXX) X-XX-XX: 1000
# (0XX)XXX-XX-XX: 971
# +38 0XX XXX XX XX: 883
#
# Processed (67.45%)
# Current stats:
# (0XX) XXX-XX-XX: 8244
# 0XX-XXX-XX-XX: 4437
# 0XX XXX XX XX: 3436
# 0XXXXXXXXX: 2804
# (0XX) XXX XX XX: 2338
# (0XXX) XX-XX-XX: 1633
# +380 (XXX) XX-XX-XX: 1571
# (0XXXX) X-XX-XX: 1004
# (0XX)XXX-XX-XX: 976
# +38 0XX XXX XX XX: 902
#
# Processed (68.15%)
# Current stats:
# (0XX) XXX-XX-XX: 8251
# 0XX-XXX-XX-XX: 4439
# 0XX XXX XX XX: 3443
# 0XXXXXXXXX: 2807
# (0XX) XXX XX XX: 2339
# (0XXX) XX-XX-XX: 1633
# +380 (XXX) XX-XX-XX: 1582
# (0XXXX) X-XX-XX: 1004
# (0XX)XXX-XX-XX: 977
# +38 0XX XXX XX XX: 903
#
# Processed (68.85%)
# Current stats:
# (0XX) XXX-XX-XX: 8257
# 0XX-XXX-XX-XX: 4443
# 0XX XXX XX XX: 3444
# 0XXXXXXXXX: 2830
# (0XX) XXX XX XX: 2352
# +380 (XXX) XX-XX-XX: 1727
# (0XXX) XX-XX-XX: 1634
# (0XXXX) X-XX-XX: 1005
# (0XX)XXX-XX-XX: 977
# +38 0XX XXX XX XX: 906
#
# Processed (69.56%)
# Current stats:
# (0XX) XXX-XX-XX: 8260
# 0XX-XXX-XX-XX: 4446
# 0XX XXX XX XX: 3448
# 0XXXXXXXXX: 2847
# (0XX) XXX XX XX: 2359
# +380 (XXX) XX-XX-XX: 1779
# (0XXX) XX-XX-XX: 1635
# (0XXXX) X-XX-XX: 1005
# (0XX)XXX-XX-XX: 977
# +38 0XX XXX XX XX: 912
#
# Processed (70.26%)
# Current stats:
# (0XX) XXX-XX-XX: 8302
# 0XX-XXX-XX-XX: 4458
# 0XX XXX XX XX: 3463
# 0XXXXXXXXX: 2859
# (0XX) XXX XX XX: 2366
# +380 (XXX) XX-XX-XX: 1842
# (0XXX) XX-XX-XX: 1638
# (0XXXX) X-XX-XX: 1006
# (0XX)XXX-XX-XX: 984
# +38 0XX XXX XX XX: 914
#
# Processed (70.96%)
# Current stats:
# (0XX) XXX-XX-XX: 8343
# 0XX-XXX-XX-XX: 4480
# 0XX XXX XX XX: 3492
# 0XXXXXXXXX: 2898
# (0XX) XXX XX XX: 2399
# +380 (XXX) XX-XX-XX: 1908
# (0XXX) XX-XX-XX: 1644
# (0XXXX) X-XX-XX: 1011
# (0XX)XXX-XX-XX: 986
# +38 0XX XXX XX XX: 915
#
# Processed (71.67%)
# Current stats:
# (0XX) XXX-XX-XX: 8470
# 0XX-XXX-XX-XX: 4664
# 0XX XXX XX XX: 3617
# 0XXXXXXXXX: 2948
# (0XX) XXX XX XX: 2559
# +380 (XXX) XX-XX-XX: 2003
# (0XXX) XX-XX-XX: 1661
# (0XXXX) X-XX-XX: 1015
# (0XX)XXX-XX-XX: 991
# +38 0XX XXX XX XX: 968
#
# Processed (72.37%)
# Current stats:
# (0XX) XXX-XX-XX: 8594
# 0XX-XXX-XX-XX: 4767
# 0XX XXX XX XX: 3789
# 0XXXXXXXXX: 3060
# (0XX) XXX XX XX: 2653
# +380 (XXX) XX-XX-XX: 2094
# (0XXX) XX-XX-XX: 1665
# (0XXXX) X-XX-XX: 1045
# (0XX)XXX-XX-XX: 1004
# +38 0XX XXX XX XX: 1001
#
# Processed (73.07%)
# Current stats:
# (0XX) XXX-XX-XX: 8598
# 0XX-XXX-XX-XX: 4799
# 0XX XXX XX XX: 3841
# 0XXXXXXXXX: 3087
# (0XX) XXX XX XX: 2672
# +380 (XXX) XX-XX-XX: 2138
# (0XXX) XX-XX-XX: 1665
# (0XXXX) X-XX-XX: 1045
# +38 0XX XXX XX XX: 1017
# (0XX)XXX-XX-XX: 1007
#
# Processed (73.77%)
# Current stats:
# (0XX) XXX-XX-XX: 8616
# 0XX-XXX-XX-XX: 4810
# 0XX XXX XX XX: 3853
# 0XXXXXXXXX: 3106
# (0XX) XXX XX XX: 2675
# +380 (XXX) XX-XX-XX: 2166
# (0XXX) XX-XX-XX: 1666
# (0XXXX) X-XX-XX: 1045
# +38 0XX XXX XX XX: 1024
# (0XX)XXX-XX-XX: 1008
#
# Processed (74.48%)
# Current stats:
# (0XX) XXX-XX-XX: 8634
# 0XX-XXX-XX-XX: 4823
# 0XX XXX XX XX: 3874
# 0XXXXXXXXX: 3119
# (0XX) XXX XX XX: 2679
# +380 (XXX) XX-XX-XX: 2178
# (0XXX) XX-XX-XX: 1666
# (0XXXX) X-XX-XX: 1045
# +38 0XX XXX XX XX: 1042
# (0XX)XXX-XX-XX: 1008
#
# Processed (75.18%)
# Current stats:
# (0XX) XXX-XX-XX: 8907
# 0XX-XXX-XX-XX: 5054
# 0XX XXX XX XX: 4074
# 0XXXXXXXXX: 3299
# (0XX) XXX XX XX: 2764
# +380 (XXX) XX-XX-XX: 2287
# (0XXX) XX-XX-XX: 1936
# (0XXXX) X-XX-XX: 1123
# +38 0XX XXX XX XX: 1071
# (0XX)XXX-XX-XX: 1057
#
# Processed (75.88%)
# Current stats:
# (0XX) XXX-XX-XX: 9247
# 0XX-XXX-XX-XX: 5351
# 0XX XXX XX XX: 4187
# 0XXXXXXXXX: 3448
# (0XX) XXX XX XX: 2866
# +380 (XXX) XX-XX-XX: 2371
# (0XXX) XX-XX-XX: 2350
# (0XXXX) X-XX-XX: 1207
# (0XX)XXX-XX-XX: 1112
# +38 0XX XXX XX XX: 1096
#
# Processed (76.58%)
# Current stats:
# (0XX) XXX-XX-XX: 9322
# 0XX-XXX-XX-XX: 5456
# 0XX XXX XX XX: 4318
# 0XXXXXXXXX: 3599
# (0XX) XXX XX XX: 2915
# +380 (XXX) XX-XX-XX: 2455
# (0XXX) XX-XX-XX: 2389
# (0XXXX) X-XX-XX: 1228
# +38 0XX XXX XX XX: 1143
# (0XX)XXX-XX-XX: 1118
#
# Processed (77.29%)
# Current stats:
# (0XX) XXX-XX-XX: 9327
# 0XX-XXX-XX-XX: 5471
# 0XX XXX XX XX: 4327
# 0XXXXXXXXX: 3608
# (0XX) XXX XX XX: 2951
# +380 (XXX) XX-XX-XX: 2500
# (0XXX) XX-XX-XX: 2389
# (0XXXX) X-XX-XX: 1228
# +38 0XX XXX XX XX: 1160
# +380XXXXXXXXX: 1129
#
# Processed (77.99%)
# Current stats:
# (0XX) XXX-XX-XX: 9331
# 0XX-XXX-XX-XX: 5489
# 0XX XXX XX XX: 4348
# 0XXXXXXXXX: 3614
# (0XX) XXX XX XX: 2953
# +380 (XXX) XX-XX-XX: 2509
# (0XXX) XX-XX-XX: 2390
# (0XXXX) X-XX-XX: 1228
# +38 0XX XXX XX XX: 1165
# +380XXXXXXXXX: 1157
#
# Processed (78.69%)
# Current stats:
# (0XX) XXX-XX-XX: 9335
# 0XX-XXX-XX-XX: 5489
# 0XX XXX XX XX: 4352
# 0XXXXXXXXX: 3614
# (0XX) XXX XX XX: 2969
# +380 (XXX) XX-XX-XX: 2522
# (0XXX) XX-XX-XX: 2390
# (0XXXX) X-XX-XX: 1228
# +38 0XX XXX XX XX: 1165
# (0XX)XXX-XX-XX: 1162
#
# Processed (79.39%)
# Current stats:
# (0XX) XXX-XX-XX: 9336
# 0XX-XXX-XX-XX: 5499
# 0XX XXX XX XX: 4373
# 0XXXXXXXXX: 3620
# (0XX) XXX XX XX: 2987
# +380 (XXX) XX-XX-XX: 2557
# (0XXX) XX-XX-XX: 2390
# (0XXXX) X-XX-XX: 1228
# +380XXXXXXXXX: 1193
# +38 0XX XXX XX XX: 1180
#
# Processed (80.10%)
# Current stats:
# (0XX) XXX-XX-XX: 9367
# 0XX-XXX-XX-XX: 5525
# 0XX XXX XX XX: 4382
# 0XXXXXXXXX: 3667
# (0XX) XXX XX XX: 2999
# +380 (XXX) XX-XX-XX: 2653
# (0XXX) XX-XX-XX: 2390
# (0XXXX) X-XX-XX: 1228
# +380XXXXXXXXX: 1218
# +38 0XX XXX XX XX: 1197
#
# Processed (80.80%)
# Current stats:
# (0XX) XXX-XX-XX: 9373
# 0XX-XXX-XX-XX: 5549
# 0XX XXX XX XX: 4390
# 0XXXXXXXXX: 3670
# (0XX) XXX XX XX: 2999
# +380 (XXX) XX-XX-XX: 2665
# (0XXX) XX-XX-XX: 2391
# +380XXXXXXXXX: 1233
# (0XXXX) X-XX-XX: 1228
# +38 0XX XXX XX XX: 1207
#
# Processed (81.50%)
# Current stats:
# (0XX) XXX-XX-XX: 9388
# 0XX-XXX-XX-XX: 5582
# 0XX XXX XX XX: 4399
# 0XXXXXXXXX: 3696
# (0XX) XXX XX XX: 3001
# +380 (XXX) XX-XX-XX: 2705
# (0XXX) XX-XX-XX: 2395
# +380XXXXXXXXX: 1250
# (0XXXX) X-XX-XX: 1228
# +38 0XX XXX XX XX: 1221
#
# Processed (82.20%)
# Current stats:
# (0XX) XXX-XX-XX: 9393
# 0XX-XXX-XX-XX: 5595
# 0XX XXX XX XX: 4407
# 0XXXXXXXXX: 3747
# (0XX) XXX XX XX: 3008
# +380 (XXX) XX-XX-XX: 2748
# (0XXX) XX-XX-XX: 2395
# +380XXXXXXXXX: 1315
# +38 0XX XXX XX XX: 1242
# (0XXXX) X-XX-XX: 1228
#
# Processed (82.91%)
# Current stats:
# (0XX) XXX-XX-XX: 9396
# 0XX-XXX-XX-XX: 5595
# 0XX XXX XX XX: 4472
# 0XXXXXXXXX: 3748
# (0XX) XXX XX XX: 3013
# +380 (XXX) XX-XX-XX: 2855
# (0XXX) XX-XX-XX: 2395
# +380XXXXXXXXX: 1316
# +38 0XX XXX XX XX: 1245
# (0XXXX) X-XX-XX: 1228
#
# Processed (83.61%)
# Current stats:
# (0XX) XXX-XX-XX: 9400
# 0XX-XXX-XX-XX: 5601
# 0XX XXX XX XX: 4490
# 0XXXXXXXXX: 3748
# +380 (XXX) XX-XX-XX: 3107
# (0XX) XXX XX XX: 3018
# (0XXX) XX-XX-XX: 2396
# 0 XXX XXX XXX: 1404
# +380XXXXXXXXX: 1322
# +38 0XX XXX XX XX: 1274
#
# Processed (84.31%)
# Current stats:
# (0XX) XXX-XX-XX: 9418
# 0XX-XXX-XX-XX: 5617
# 0XX XXX XX XX: 4503
# 0XXXXXXXXX: 3770
# +380 (XXX) XX-XX-XX: 3137
# (0XX) XXX XX XX: 3031
# (0XXX) XX-XX-XX: 2397
# 0 XXX XXX XXX: 1420
# +380XXXXXXXXX: 1337
# +38 0XX XXX XX XX: 1279
#
# Processed (85.01%)
# Current stats:
# (0XX) XXX-XX-XX: 9433
# 0XX-XXX-XX-XX: 5646
# 0XX XXX XX XX: 4525
# 0XXXXXXXXX: 3798
# +380 (XXX) XX-XX-XX: 3151
# (0XX) XXX XX XX: 3037
# (0XXX) XX-XX-XX: 2401
# 0 XXX XXX XXX: 1430
# +380XXXXXXXXX: 1351
# +38 0XX XXX XX XX: 1297
#
# Processed (85.72%)
# Current stats:
# (0XX) XXX-XX-XX: 9469
# 0XX-XXX-XX-XX: 5682
# 0XX XXX XX XX: 4566
# 0XXXXXXXXX: 3841
# +380 (XXX) XX-XX-XX: 3172
# (0XX) XXX XX XX: 3054
# (0XXX) XX-XX-XX: 2403
# 0 XXX XXX XXX: 1439
# +380XXXXXXXXX: 1380
# +38 0XX XXX XX XX: 1304
#
# Processed (86.42%)
# Current stats:
# (0XX) XXX-XX-XX: 9507
# 0XX-XXX-XX-XX: 5718
# 0XX XXX XX XX: 4588
# 0XXXXXXXXX: 3862
# +380 (XXX) XX-XX-XX: 3205
# (0XX) XXX XX XX: 3060
# (0XXX) XX-XX-XX: 2403
# 0 XXX XXX XXX: 1460
# +380XXXXXXXXX: 1444
# +38 0XX XXX XX XX: 1321
#
# Processed (87.12%)
# Current stats:
# (0XX) XXX-XX-XX: 9532
# 0XX-XXX-XX-XX: 5747
# 0XX XXX XX XX: 4601
# 0XXXXXXXXX: 3886
# +380 (XXX) XX-XX-XX: 3216
# (0XX) XXX XX XX: 3064
# (0XXX) XX-XX-XX: 2404
# 0 XXX XXX XXX: 1463
# +380XXXXXXXXX: 1452
# +38 0XX XXX XX XX: 1330
#
# Processed (87.82%)
# Current stats:
# (0XX) XXX-XX-XX: 9581
# 0XX-XXX-XX-XX: 5790
# 0XX XXX XX XX: 4618
# 0XXXXXXXXX: 3906
# +380 (XXX) XX-XX-XX: 3245
# (0XX) XXX XX XX: 3074
# (0XXX) XX-XX-XX: 2407
# 0 XXX XXX XXX: 1481
# +380XXXXXXXXX: 1465
# +38 0XX XXX XX XX: 1332
#
# Processed (88.53%)
# Current stats:
# (0XX) XXX-XX-XX: 9651
# 0XX-XXX-XX-XX: 5843
# 0XX XXX XX XX: 4653
# 0XXXXXXXXX: 3989
# +380 (XXX) XX-XX-XX: 3276
# (0XX) XXX XX XX: 3110
# (0XXX) XX-XX-XX: 2413
# +380XXXXXXXXX: 1512
# 0 XXX XXX XXX: 1493
# +38 0XX XXX XX XX: 1347
#
# Processed (89.23%)
# Current stats:
# (0XX) XXX-XX-XX: 9675
# 0XX-XXX-XX-XX: 5899
# 0XX XXX XX XX: 4669
# 0XXXXXXXXX: 4005
# +380 (XXX) XX-XX-XX: 3303
# (0XX) XXX XX XX: 3116
# (0XXX) XX-XX-XX: 2414
# +380XXXXXXXXX: 1546
# 0 XXX XXX XXX: 1504
# +38 0XX XXX XX XX: 1451
#
# Processed (89.93%)
# Current stats:
# (0XX) XXX-XX-XX: 9704
# 0XX-XXX-XX-XX: 5918
# 0XX XXX XX XX: 4691
# 0XXXXXXXXX: 4017
# +380 (XXX) XX-XX-XX: 3334
# (0XX) XXX XX XX: 3140
# (0XXX) XX-XX-XX: 2417
# +380XXXXXXXXX: 1596
# 0 XXX XXX XXX: 1516
# +38 0XX XXX XX XX: 1484
#
# Processed (90.64%)
# Current stats:
# (0XX) XXX-XX-XX: 9790
# 0XX-XXX-XX-XX: 5930
# 0XX XXX XX XX: 4696
# 0XXXXXXXXX: 4032
# +380 (XXX) XX-XX-XX: 3378
# (0XX) XXX XX XX: 3145
# (0XXX) XX-XX-XX: 2425
# +380XXXXXXXXX: 1607
# 0 XXX XXX XXX: 1526
# +38 0XX XXX XX XX: 1494
#
# Processed (91.34%)
# Current stats:
# (0XX) XXX-XX-XX: 9848
# 0XX-XXX-XX-XX: 5961
# 0XX XXX XX XX: 4708
# 0XXXXXXXXX: 4056
# +380 (XXX) XX-XX-XX: 3422
# (0XX) XXX XX XX: 3154
# (0XXX) XX-XX-XX: 2435
# +380XXXXXXXXX: 1616
# 0 XXX XXX XXX: 1534
# +38 0XX XXX XX XX: 1508
#
# Processed (92.04%)
# Current stats:
# (0XX) XXX-XX-XX: 9908
# 0XX-XXX-XX-XX: 5982
# 0XX XXX XX XX: 4722
# 0XXXXXXXXX: 4072
# +380 (XXX) XX-XX-XX: 3462
# (0XX) XXX XX XX: 3168
# (0XXX) XX-XX-XX: 2438
# +380XXXXXXXXX: 1623
# 0 XXX XXX XXX: 1546
# +38 0XX XXX XX XX: 1525
#
# Processed (92.74%)
# Current stats:
# (0XX) XXX-XX-XX: 9948
# 0XX-XXX-XX-XX: 6021
# 0XX XXX XX XX: 4733
# 0XXXXXXXXX: 4082
# +380 (XXX) XX-XX-XX: 3497
# (0XX) XXX XX XX: 3178
# (0XXX) XX-XX-XX: 2440
# +380XXXXXXXXX: 1631
# 0 XXX XXX XXX: 1556
# +38 0XX XXX XX XX: 1542
#
# Processed (93.45%)
# Current stats:
# (0XX) XXX-XX-XX: 10000
# 0XX-XXX-XX-XX: 6047
# 0XX XXX XX XX: 4749
# 0XXXXXXXXX: 4088
# +380 (XXX) XX-XX-XX: 3533
# (0XX) XXX XX XX: 3194
# (0XXX) XX-XX-XX: 2442
# +380XXXXXXXXX: 1638
# 0 XXX XXX XXX: 1559
# +38 0XX XXX XX XX: 1549
#
# Processed (94.15%)
# Current stats:
# (0XX) XXX-XX-XX: 10048
# 0XX-XXX-XX-XX: 6068
# 0XX XXX XX XX: 4770
# 0XXXXXXXXX: 4107
# +380 (XXX) XX-XX-XX: 3577
# (0XX) XXX XX XX: 3210
# (0XXX) XX-XX-XX: 2452
# +380XXXXXXXXX: 1649
# +38 0XX XXX XX XX: 1563
# 0 XXX XXX XXX: 1563
#
# Processed (94.85%)
# Current stats:
# (0XX) XXX-XX-XX: 10111
# 0XX-XXX-XX-XX: 6084
# 0XX XXX XX XX: 4779
# 0XXXXXXXXX: 4131
# +380 (XXX) XX-XX-XX: 3625
# (0XX) XXX XX XX: 3223
# (0XXX) XX-XX-XX: 2452
# +380XXXXXXXXX: 1656
# +38 0XX XXX XX XX: 1582
# 0 XXX XXX XXX: 1569
#
# Processed (95.55%)
# Current stats:
# (0XX) XXX-XX-XX: 10166
# 0XX-XXX-XX-XX: 6101
# 0XX XXX XX XX: 4801
# 0XXXXXXXXX: 4148
# +380 (XXX) XX-XX-XX: 3662
# (0XX) XXX XX XX: 3241
# (0XXX) XX-XX-XX: 2455
# +380XXXXXXXXX: 1670
# +38 0XX XXX XX XX: 1608
# 0 XXX XXX XXX: 1575
#
# Processed (96.26%)
# Current stats:
# (0XX) XXX-XX-XX: 10218
# 0XX-XXX-XX-XX: 6126
# 0XX XXX XX XX: 4837
# 0XXXXXXXXX: 4169
# +380 (XXX) XX-XX-XX: 3720
# (0XX) XXX XX XX: 3253
# (0XXX) XX-XX-XX: 2455
# +380XXXXXXXXX: 1685
# +38 0XX XXX XX XX: 1626
# 0 XXX XXX XXX: 1594
#
# Processed (96.96%)
# Current stats:
# (0XX) XXX-XX-XX: 10786
# 0XX-XXX-XX-XX: 6211
# 0XX XXX XX XX: 4888
# 0XXXXXXXXX: 4209
# +380 (XXX) XX-XX-XX: 3776
# (0XX) XXX XX XX: 3357
# (0XXX) XX-XX-XX: 2456
# +380XXXXXXXXX: 1710
# +38 0XX XXX XX XX: 1656
# 0 XXX XXX XXX: 1595
#
# Processed (97.66%)
# Current stats:
# (0XX) XXX-XX-XX: 10977
# 0XX-XXX-XX-XX: 6247
# 0XX XXX XX XX: 4897
# 0XXXXXXXXX: 4212
# +380 (XXX) XX-XX-XX: 3846
# (0XX) XXX XX XX: 3375
# (0XXX) XX-XX-XX: 2465
# +380XXXXXXXXX: 1712
# +38 0XX XXX XX XX: 1681
# 0 XXX XXX XXX: 1602
#
# Processed (98.36%)
# Current stats:
# (0XX) XXX-XX-XX: 11633
# 0XX-XXX-XX-XX: 6378
# 0XX XXX XX XX: 4927
# 0XXXXXXXXX: 4227
# +380 (XXX) XX-XX-XX: 3927
# (0XX) XXX XX XX: 3401
# (0XXX) XX-XX-XX: 2468
# +38 0XX XXX XX XX: 1732
# +380XXXXXXXXX: 1719
# 0 XXX XXX XXX: 1611
#
# Processed (99.07%)
# Current stats:
# (0XX) XXX-XX-XX: 11800
# 0XX-XXX-XX-XX: 6401
# 0XX XXX XX XX: 4959
# 0XXXXXXXXX: 4230
# +380 (XXX) XX-XX-XX: 4017
# (0XX) XXX XX XX: 3433
# (0XXX) XX-XX-XX: 2471
# +38 0XX XXX XX XX: 1744
# +380XXXXXXXXX: 1720
# 0 XXX XXX XXX: 1614
#
# Processed (99.77%)
# Final stats:
# (0XX) XXX-XX-XX: 11827
# 0XX-XXX-XX-XX: 6407
# 0XX XXX XX XX: 4964
# 0XXXXXXXXX: 4232
# +380 (XXX) XX-XX-XX: 4047
# (0XX) XXX XX XX: 3443
# (0XXX) XX-XX-XX: 2474
# +38 0XX XXX XX XX: 1751
# +380XXXXXXXXX: 1723
# 0 XXX XXX XXX: 1616
# 0-XXX-XXX-XXX: 1565
# (0XXXX) X-XX-XX: 1280
# (0XX)XXX-XX-XX: 1271
# +38 (0XX) XXX-XX-XX: 994
# +38 (0XX) XXX XX XX: 777
# 0 XXX XX XXXX: 662
# 0XX-XX-XX-XXX: 577
# 0 XXX XX XX XX: 533
# 0XX XXX-XX-XX: 521
# 0XX XX XX XXX: 512
# 0XX XXX XXXX: 487
# (0XX)XXXXXXX: 466
# 0-XXX-XX-XX-XX: 437
# 0XX XXXXXXX: 393
# +380 (XX) XXX XX XX: 383
# (0XXXX)XXXXX: 365
# (0XX) XXXXXXX: 355
# +380 XX XXX XX XX: 339
# (0XXX) XX XX XX: 315
# 0XXX XXX XXX: 307
# +38(0XX)XXX-XX-XX: 293
# (0XX)-XXX-XX-XX: 274
# (0XX) XX-XX-XXX: 261
# 0XX-XXX-XXXX: 253
# 0XX-XXXXXXX: 242
# 38 (0XX) XXX XX XX: 232
# (0XXX)XX-XX-XX: 226
# +38 0XX XXX XXXX: 186
# (0XX) XX XX XXX: 175
# (0XX) XXX XXXX: 158
# (0XX) XXX-XXXX: 156
# (0XXX) XXXXXX: 146
# +380 XX XXX XXXX: 134
# 0XXX-XXX-XXX: 131
# +380 (XX) XXX-XX-XX: 129
# (0XXXX)X-XX-XX: 127
# +38(0XX) XXX-XX-XX: 116
# +38 0XX XXX-XX-XX: 99
# +380XX XXX XX XX: 92
# +380 XX XXX-XX-XX: 87
# (0XX)XXX XX XX: 86
# 38 0XX XXX XX XX: 82
# 380XXXXXXXXX: 81
# 0XXXXX XX XX: 77
# (0XXXX) XXXXX: 74
# 0XXX XX XX XX: 73
# +38 (0XXX) XX-XX-XX: 72
# +380XX-XXX-XX-XX: 68
# (0XXX)XXXXXX: 68
# 0XX XX XXX XX: 66
# +38(0XX) XXX XX XX: 65
# +38 0XX-XXX-XX-XX: 61
# +38 0XX XXXXXXX: 58
# 0XX-XX-XXX-XX: 56
# 0 (XX) XXX XX XX: 50
# (0XXXX) X XX XX: 50
# +38(0XX)XXXXXXX: 49
# +38 (0XX) XXXXXXX: 46
# (0XX)XX-XX-XXX: 46
# 0XX XXX XX-XX: 45
# +38 0XX XX XX XXX: 44
# 0XX-XXXX-XXX: 43
# 0XXX-XX-XX-XX: 39
# 0XXXX-XXXXX: 39
# +38 (0XX) XXX XXXX: 37
# (0XX) XX XXX XX: 36
# 0 XXX-XXX-XXX: 33
# (0XX) XX-XXX-XX: 31
# 38 (0XX) XXX-XX-XX: 28
# 0XXX-XX-XXXX: 27
# +380XX XXXXXXX: 26
# (0XXX)-XX-XX-XX: 26
# 0XX XXXX XXX: 23
# +380XX XX XX XXX: 22
# +38(0XX)-XXX-XX-XX: 22
# 0-XXX-XXXXXX: 20
# 0XXXX XXXXX: 20
# (0XX)-XX-XX-XXX: 20
# 0 XX XXX XX XX: 20
# +38 (0XX) XXX-XXXX: 19
# +380 XX XX XX XXX: 19
# +38 (0XXXX) X-XX-XX: 18
# +38 0XX) XXX-XX-XX: 17
# 0-XXX-XX-XXXX: 17
# 0XX-XXX XX XX: 17
# 0XXX XX XXXX: 17
# +38 (0XX)XXX XX XX: 17
# +38 (0XX)XXX-XX-XX: 16
# 0XXXXXXX XX: 16
# +38(0XX) XXXXXXX: 16
# +380 XXXXXXXXX: 15
# 0XX XXX-XXXX: 15
# +38(0XX)XXX XX XX: 15
# +38 (0XX) XX XX XXX: 15
# 0 XXX XXXXXX: 15
# 38 0XX XXX XXXX: 14
# (0XX)XX XX XXX: 14
# +38 0XXXXXXXXX: 14
# 0XXXXX-XX-XX: 14
# +380XX XXX-XX-XX: 13
# 0XX XX-XX-XXX: 13
# (0XX)XXX-XXXX: 13
# +380XX XXX XXXX: 13
# 0(XX) XXX XX XX: 13
# +380 (XX) XXX-XXXX: 13
# +38(0XXX) XX-XX-XX: 12
# 0XXX XXXXXX: 12
# +38 0XX XX XXX XX: 12
# +38 0XX) XXXXXXX: 12
# +380XXXXX XX XX: 11
# 380 (XX) XXX XX XX: 11
# +38(0XXX)XXXXXX: 11
# 0 XXX XXX-XXX: 11
# (0XXXX)-X-XX-XX: 11
# 380 XX XXX XXXX: 10
# 380 XX XXX XX XX: 10
# +380 (XX) XXX XXXX: 10
# 0 XX XXX XXXX: 10
# +38 (0XX) XXXX XXX: 10
# +38 (0XX)-XXX-XX-XX: 10
# 380 XX XXX-XX-XX: 10
# +38 0XX) XXX XX XX: 9
# +38 (0XX) XX-XX-XXX: 9
# 0(XX) XXX-XX-XX: 9
# 38 (0XX) XXX XXXX: 9
# (0XX)XXX XXXX: 8
# 0 (XX) XXX-XX-XX: 8
# (0XX) XXXX XXX: 8
# +380(XX)XXX-XX-XX: 8
# 0XX XXXXX XX: 8
# (0XXXX) XXX XX: 8
# +38(0XXXX)XXXXX: 8
# +38 0XXXXX XX XX: 7
# (0XX)XXXX-XXX: 7
# +380 XX XXXXXXX: 7
# (0XX) XXX XX-XX: 6
# +380(XX) XXX XX XX: 6
# 0XX-XXXXX-XX: 6
# (0XXX)XX XX XX: 6
# 38(0XX)XXX-XX-XX: 6
# +38(0XX)XX-XX-XXX: 6
# +380XX) XXX XX XX: 5
# 0XXXXX XXXX: 5
# +38(0XX)XXX-XXXX: 5
# 0-XX-XXX-XX-XX: 5
# +38 (0XXX) XX XX XX: 5
# +38 0XX-XXX-XXXX: 5
# (0XX)XX-XXX-XX: 5
# +38(0XXX)XX-XX-XX: 5
# +380XX) XXX-XX-XX: 5
# (0XX) XXXX-XXX: 5
# (0XX) XX XXXXX: 5
# +380 XXX XXX XXX: 5
# 380XX-XXX-XX-XX: 4
# +38 0XX XXXX XXX: 4
# 0XXXXXX XXX: 4
# +38(0XX) XX XX XXX: 4
# 38 0XX XXX-XX-XX: 4
# +38 0XX) XXX XXXX: 4
# +380XX-XXXXXXX: 4
# +38 (0XX) XX XXX XX: 4
# 0XX-XX-XXXXX: 4
# (0XX)-XXX-XXXX: 4
# +380 (XX) XXXXXXX: 4
# (0XX) XXXXX XX: 4
# +380(XX)-XXX-XX-XX: 4
# (0XXXX) XXX-XX: 4
# +380 (XX) XX-XX-XXX: 4
# 38 (0XX) XXXXXXX: 4
# +380XX) XXX-XXXX: 3
# 0XXX-XXXXXX: 3
# +380(XX) XXXXXXX: 3
# 380 XX XXXXXXX: 3
# (0XXXX) X XXXX: 3
# 380XX XXX XX XX: 3
# 38 0XX XX XX XXX: 3
# 0-XXX-XXXX-XX: 3
# 38(0XX) XXX XX XX: 3
# +38(0XX)-XXX-XXXX: 3
# +38 0XX-XX-XX-XXX: 3
# 380XXXXX XX XX: 3
# +38 0XX XX XXXXX: 3
# 0 XXX-XX-XX-XX: 3
# +380XX) XXXXXXX: 3
# (0XX) XXX-XX XX: 3
# +38(0XX) XX-XX-XXX: 3
# +380(XX) XXX-XX-XX: 3
# +38 0XX XXXXX XX: 3
# 0XXX XXXX XX: 3
# 38(0XX)XXXXXXX: 3
# 0 XXX XX-XX-XX: 3
# 0(XX) XXX XXXX: 3
# +38(0XX) XXX XXXX: 3
# 0 XXX XXXX XX: 3
# +380 XX-XXX-XX-XX: 3
# +38 0XX XXX-XXXX: 2
# 0XX XX-XXX-XX: 2
# 0XXXX-XXX XX: 2
# 0XX-XXX-XX XX: 2
# 0XX XX XXXXX: 2
# 380XX XX XX XXX: 2
# +38 (0XX) XXX XX-XX: 2
# +38(0XXX) XXXXXX: 2
# 0XXX XXX-XXX: 2
# 380XX) XXX-XXXX: 2
# 0XXXX-XX-XXX: 2
# +38 (0XX) XX-XXX-XX: 2
# 0-XX-XXX-XXXX: 2
# 0-XX XXX-XX-XX: 2
# (0XX)XXXX XXX: 2
# +38 (0XXXX)X-XX-XX: 2
# 38(0XX) XXX-XX-XX: 2
# +38 0XXXX XXXXX: 2
# 0(XX)XXXXXXX: 2
# +380XX-XXX-XXXX: 2
# 38 0XX XXXXXXX: 2
# +380 XX XXXX XXX: 2
# +38(0XXX)-XX-XX-XX: 2
# +38 (0XX)XXXXXXX: 2
# 0 XXX-XX-XXXX: 1
# 0 (XX) XXX XXXX: 1
# 0(XX)XXX XX XX: 1
# +38 (0XX) XXX-XX XX: 1
# (0XX)-XXX XX XX: 1
# +38 0XX) XX-XX-XXX: 1
# (0XXXX)XXX-XX: 1
# 380XX XXX XXXX: 1
# 0 XX-XXXXXXX: 1
# 0(XX)-XXX-XX-XX: 1
# (0XX)XX XXX XX: 1
# 380(XX)XXX-XX-XX: 1
# +38 (0XXXX) XXXXX: 1
# 380 (XX) XXX-XX-XX: 1
# 380XX) XXX XX XX: 1
# +38 0XX XXX-XX XX: 1
# 380XX XXX-XXXX: 1
# 38 (0XX) XXX-XXXX: 1
# 38 0XXXXX XX XX: 1
# 380XX XXXXXXX: 1
# 38 (0XX) XX XX XXX: 1
# +380 XX) XXX-XX-XX: 1
# (0XX)XXXXX XX: 1
# +380XX)XXX XXXX: 1
# 380 XX XX XX XXX: 1
# +38(0XX)-XXXXXXX: 1
# 0 XX XX XX XXX: 1
# 0XXX XX-XX-XX: 1
# (0XXXX) X-XX XX: 1
# 0XX XX XX XXX: 1
# 38 (0XX) XX-XX-XXX: 1
# +380XX-XX-XX-XXX: 1
# +380 (XX)XXX XX XX: 1
# +380-XXX-XX-XX-XX: 1
# 380XXXXX XXXX: 1
# 38 0XX) XXX-XX-XX: 1
# +380XXXXX XXXX: 1
# 380XX)XXXXXXX: 1
# 380 XX) XXX-XX-XX: 1
# +38(0XX-XXX-XX-XX: 1
# 380 XX) XXX XX XX: 1
# 38 0XX) XXX XX XX: 1
# 0(XX) XX XX XXX: 1
# 0(XX)XXX-XX-XX: 1
# +38(0XX)-XX-XX-XXX: 1
# +38(0XXX)XX XX XX: 1
# 0XX-XXX XX-XX: 1
# +38 0XXX XX XX XX: 1
# +380 XXX XX XX XX: 1
# 38 (0XX XXXXXXX: 1
# +38(0XXXX) X-XX-XX: 1
# +38(0XX) XXX XX-XX: 1
# +38 (0XX XXX XXXX: 1
# 0-XXX XX-XX-XX: 1
# +380 XXX XX-XX-XX: 1
# +38(0XXX) XX XX XX: 1
# +380-XXX-XXX-XXX: 1
# (0XXXX) X-XXXX: 1
# +380 (XX)XXXXXXX: 1
# 380(XX) XXX XX XX: 1
# (0XX)-XXXX-XXX: 1
# 0 XXX-XXXXXX: 1
# 0XXXXX-XXXX: 1
# +380XX XX XXX XX: 1
# +380(XX) XXX-XXXX: 1
# +380 XX XX XXX XX: 1
# +380XXXX XXX XX: 1
# +380(XX)XXXXXXX: 1
# +38(0XX)XX XX XXX: 1
# 0-XXX XXX-XXX: 1
# 38 0XXXXX-XX-XX: 1
# (0XXXX)X XX XX: 1
# +380XXXXX-XX-XX: 1
# After normalization:
# +380 (XX) XXX-XX-XX: 51489
# +380 (XXX) XX-XX-XX: 9923

# %% [markdown]
# ## 4.2.2 Distribution Before Normalization

# %%
import pandas as pd

stats_before_normalization_df = pd.DataFrame(stats_before_normalization.items(), columns=['Phone Number', 'Count'])
stats_before_normalization_df['Percentage'] = stats_before_normalization_df['Count'] / stats_before_normalization_df['Count'].sum() * 100
stats_before_normalization_df = stats_before_normalization_df.sort_values(by='Count', ascending=False)
stats_before_normalization_df = stats_before_normalization_df.reset_index(drop=True)

# Count total number of distinct formats
total_formats = len(stats_before_normalization_df)

# Count formats that appear only once
formats_appearing_once = len(stats_before_normalization_df[stats_before_normalization_df['Count'] == 1])

# Calculate percentage of the top 10 formats
top_10_percentage = stats_before_normalization_df.head(10)['Count'].sum() / stats_before_normalization_df['Count'].sum() * 100

# Calculate the percentage for the remaining formats
remaining_percentage = 100 - top_10_percentage

print(f"Total distinct formats: {total_formats}")
print(f"Formats appearing only once: {formats_appearing_once}")
print(f"Top 10 formats percentage: {top_10_percentage:.1f}%")
print(f"Remaining {total_formats - 10} formats percentage: {remaining_percentage:.1f}%")

stats_before_normalization_df.head(10)
# Out:
# Total distinct formats: 302
# Formats appearing only once: 73
# Top 10 formats percentage: 69.2%
# Remaining 292 formats percentage: 30.8%
#           Phone Number  Count  Percentage
# 0      (0XX) XXX-XX-XX  11827   19.258451
# 1        0XX-XXX-XX-XX   6407   10.432814
# 2        0XX XXX XX XX   4964    8.083111
# 3           0XXXXXXXXX   4232    6.891161
# 4  +380 (XXX) XX-XX-XX   4047    6.589917
# 5      (0XX) XXX XX XX   3443    5.606396
# 6      (0XXX) XX-XX-XX   2474    4.028529
# 7    +38 0XX XXX XX XX   1751    2.851234
# 8        +380XXXXXXXXX   1723    2.805641
# 9        0 XXX XXX XXX   1616    2.631408

# %% [markdown]
# ## 4.2.3 Distribution After Normalization

# %%
stats_after_normalization_df = pd.DataFrame(stats_after_normalization.items(), columns=['Phone Number', 'Count'])
stats_after_normalization_df['Percentage'] = stats_after_normalization_df['Count'] / stats_after_normalization_df['Count'].sum() * 100
stats_after_normalization_df = stats_after_normalization_df.sort_values(by='Count', ascending=False)
stats_after_normalization_df = stats_after_normalization_df.reset_index(drop=True)

stats_after_normalization_df
# Out:
#           Phone Number  Count  Percentage
# 0  +380 (XX) XXX-XX-XX  51489    83.84192
# 1  +380 (XXX) XX-XX-XX   9923    16.15808

# %% [markdown]
# # Apostrophe and Quotation Mark Normalization Results Calculation

# %%
from sources.normalizers.constants import Constants
from sources.normalizers.apostrophe_normalizer import ApostropheNormalizer
from sources.normalizers.quotation_marks_normalizer import QuotationMarksNormalizer
from sources.normalizers.redundant_apostrophe_spaces_normalizer import RedundantApostropheSpacesNormalizer

apostrophe_stats_before_normalization = {}
quotation_marks_stats_before_normalization = {}
apostrophe_stats_after_apostrophe_normalization = {}
quotation_marks_stats_after_quotation_marks_normalization = {}

warning_apostrophe_count = 0
error_apostrophe_count = 0
warning_quotation_mark_count = 0
error_quotation_mark_count = 0

current_news_number = 0
progress_step = 100_000

def setup_stats():
    print("Setting up stats")
    print("Apostrophes:", Constants.APOSTROPHES)
    print("Quotes:",Constants.QUOTATION_MARKS)
    
    for apostrophe in Constants.APOSTROPHES:
        apostrophe_stats_before_normalization[apostrophe] = 0
        apostrophe_stats_after_apostrophe_normalization[apostrophe] = 0
    
    for quotation_mark in Constants.QUOTATION_MARKS:
        quotation_marks_stats_before_normalization[quotation_mark] = 0
        quotation_marks_stats_after_quotation_marks_normalization[quotation_mark] = 0

def calculate_apostrophe_and_quotation_marks_normalization(news_text: str):
    global warning_apostrophe_count, error_apostrophe_count, warning_quotation_mark_count, error_quotation_mark_count
    
    # REDUNDANT APOSTROPHE SPACES
    normalized_text, _, _ = RedundantApostropheSpacesNormalizer.normalize(news_text)
    
    # INITIAL STATS
    for pattern in apostrophe_stats_before_normalization.keys():
        apostrophe_stats_before_normalization[pattern] += normalized_text.count(pattern)
    
    for pattern in quotation_marks_stats_before_normalization.keys():
        quotation_marks_stats_before_normalization[pattern] += normalized_text.count(pattern)

    # APOSTROPHE
    apostrophe_normalization_result = ApostropheNormalizer.normalize(normalized_text)
    
    normalized_text = apostrophe_normalization_result[0]
    warning_apostrophe_count += len(apostrophe_normalization_result[1])
    error_apostrophe_count += len(apostrophe_normalization_result[2])
    
    for pattern in apostrophe_stats_after_apostrophe_normalization.keys():
        apostrophe_stats_after_apostrophe_normalization[pattern] += normalized_text.count(pattern)
    
    
    # QUOTATION MARKS
    quotation_marks_normalization_result = QuotationMarksNormalizer.normalize(normalized_text)
    normalized_text = quotation_marks_normalization_result[0]
    warning_quotation_mark_count += len(quotation_marks_normalization_result[1])
    error_quotation_mark_count += len(quotation_marks_normalization_result[2])
    
    for pattern in quotation_marks_stats_after_quotation_marks_normalization.keys():
        quotation_marks_stats_after_quotation_marks_normalization[pattern] += normalized_text.count(pattern)

setup_stats()

for news_text in read_news_stream(corpus_path):
    current_news_number += 1
    calculate_apostrophe_and_quotation_marks_normalization(news_text)
    
    if current_news_number % progress_step == 0:
        print(f'\nProcessed ({current_news_number / total_news_count * 100:.2f}%) \n')

print("Finished processing")
# Out:
# Setting up stats
# Apostrophes: ["'", 'ʹ', 'ʻ', 'ʼ', '‘', '’', '`']
# Quotes: ['"', '«', '»', '“', '”', '‟', '„', '❝', '❞']
#
# Processed (0.70%)
#
# Processed (1.41%)
#
# Processed (2.11%)
#
# Processed (2.81%)
#
# Processed (3.51%)
#
# Processed (4.22%)
#
# Processed (4.92%)
#
# Processed (5.62%)
#
# Processed (6.32%)
#
# Processed (7.03%)
#
# Processed (7.73%)
#
# Processed (8.43%)
#
# Processed (9.13%)
#
# Processed (9.84%)
#
# Processed (10.54%)
#
# Processed (11.24%)
#
# Processed (11.94%)
#
# Processed (12.65%)
#
# Processed (13.35%)
#
# Processed (14.05%)
#
# Processed (14.75%)
#
# Processed (15.46%)
#
# Processed (16.16%)
#
# Processed (16.86%)
#
# Processed (17.56%)
#
# Processed (18.27%)
#
# Processed (18.97%)
#
# Processed (19.67%)
#
# Processed (20.38%)
#
# Processed (21.08%)
#
# Processed (21.78%)
#
# Processed (22.48%)
#
# Processed (23.19%)
#
# Processed (23.89%)
#
# Processed (24.59%)
#
# Processed (25.29%)
#
# Processed (26.00%)
#
# Processed (26.70%)
#
# Processed (27.40%)
#
# Processed (28.10%)
#
# Processed (28.81%)
#
# Processed (29.51%)
#
# Processed (30.21%)
#
# Processed (30.91%)
#
# Processed (31.62%)
#
# Processed (32.32%)
#
# Processed (33.02%)
#
# Processed (33.72%)
#
# Processed (34.43%)
#
# Processed (35.13%)
#
# Processed (35.83%)
#
# Processed (36.54%)
#
# Processed (37.24%)
#
# Processed (37.94%)
#
# Processed (38.64%)
#
# Processed (39.35%)
#
# Processed (40.05%)
#
# Processed (40.75%)
#
# Processed (41.45%)
#
# Processed (42.16%)
#
# Processed (42.86%)
#
# Processed (43.56%)
#
# Processed (44.26%)
#
# Processed (44.97%)
#
# Processed (45.67%)
#
# Processed (46.37%)
#
# Processed (47.07%)
#
# Processed (47.78%)
#
# Processed (48.48%)
#
# Processed (49.18%)
#
# Processed (49.88%)
#
# Processed (50.59%)
#
# Processed (51.29%)
#
# Processed (51.99%)
#
# Processed (52.69%)
#
# Processed (53.40%)
#
# Processed (54.10%)
#
# Processed (54.80%)
#
# Processed (55.51%)
#
# Processed (56.21%)
#
# Processed (56.91%)
#
# Processed (57.61%)
#
# Processed (58.32%)
#
# Processed (59.02%)
#
# Processed (59.72%)
#
# Processed (60.42%)
#
# Processed (61.13%)
#
# Processed (61.83%)
#
# Processed (62.53%)
#
# Processed (63.23%)
#
# Processed (63.94%)
#
# Processed (64.64%)
#
# Processed (65.34%)
#
# Processed (66.04%)
#
# Processed (66.75%)
#
# Processed (67.45%)
#
# Processed (68.15%)
#
# Processed (68.85%)
#
# Processed (69.56%)
#
# Processed (70.26%)
#
# Processed (70.96%)
#
# Processed (71.67%)
#
# Processed (72.37%)
#
# Processed (73.07%)
#
# Processed (73.77%)
#
# Processed (74.48%)
#
# Processed (75.18%)
#
# Processed (75.88%)
#
# Processed (76.58%)
#
# Processed (77.29%)
#
# Processed (77.99%)
#
# Processed (78.69%)
#
# Processed (79.39%)
#
# Processed (80.10%)
#
# Processed (80.80%)
#
# Processed (81.50%)
#
# Processed (82.20%)
#
# Processed (82.91%)
#
# Processed (83.61%)
#
# Processed (84.31%)
#
# Processed (85.01%)
#
# Processed (85.72%)
#
# Processed (86.42%)
#
# Processed (87.12%)
#
# Processed (87.82%)
#
# Processed (88.53%)
#
# Processed (89.23%)
#
# Processed (89.93%)
#
# Processed (90.64%)
#
# Processed (91.34%)
#
# Processed (92.04%)
#
# Processed (92.74%)
#
# Processed (93.45%)
#
# Processed (94.15%)
#
# Processed (94.85%)
#
# Processed (95.55%)
#
# Processed (96.26%)
#
# Processed (96.96%)
#
# Processed (97.66%)
#
# Processed (98.36%)
#
# Processed (99.07%)
#
# Processed (99.77%)
# {"'": 7465048, 'ʹ': 214, 'ʻ': 10, 'ʼ': 144521, '‘': 12824, '’': 4693904, '`': 20895}
# {"'": 5519, 'ʹ': 0, 'ʻ': 0, 'ʼ': 12302968, '‘': 209, '’': 1226, '`': 397}

# %% [markdown]
# # 4.3 Apostrophe Normalization Results

# %%
import pandas as pd
import unicodedata
from helpers.unicode import unicode

# Assuming these variables already contain the count data:
# apostrophe_stats_before_normalization = {...}
# apostrophe_stats_after_apostrophe_normalization = {...}
# warning_apostrophe_count, error_apostrophe_count = ...

# Create a dataframe for apostrophe statistics
def create_apostrophe_results_df(before_stats, after_stats):
    # Convert dictionaries to dataframe
    data = []

    for symbol in before_stats.keys():
        before_count = before_stats[symbol]
        after_count = after_stats[symbol]

        # Get unicode code point
        unicode_code = unicode(symbol)

        data.append({
            'Unicode': unicode_code,
            'Symbol': symbol,
            'Before Normalization': before_count,
            'After Normalization': after_count
        })

    df = pd.DataFrame(data)

    # Calculate total counts
    total_before = df['Before Normalization'].sum()
    total_after = df['After Normalization'].sum()

    # Add percentage columns
    df['Percentage Before'] = (df['Before Normalization'] / total_before * 100).round(4)
    df['Percentage After'] = (df['After Normalization'] / total_after * 100).round(4)

    # Sort by count before normalization
    df = df.sort_values(by='Before Normalization', ascending=False)

    # Add a row for totals
    totals_row = pd.DataFrame([{
        'Unicode': 'Total',
        'Symbol': '',
        'Before Normalization': total_before,
        'After Normalization': total_after,
        'Percentage Before': 100,
        'Percentage After': 100
    }])

    df = pd.concat([df, totals_row])

    # Reformat the table for readability in publication
    publication_table = df[['Unicode', 'Symbol', 'Before Normalization', 'Percentage Before',
                            'After Normalization', 'Percentage After']]

    return df, publication_table

# Calculate additional statistics for analysis
def calculate_apostrophe_statistics(df, warning_count, error_count):
    # Exclude the 'Total' row for these calculations
    df_no_total = df[df['Unicode'] != 'Total']

    # Total symbols before normalization
    total_before = df_no_total['Before Normalization'].sum()

    # Total symbols after normalization
    total_after = df_no_total['After Normalization'].sum()

    # Standard apostrophe (U+02BC) percentage before and after
    standard_apostrophe_before = df_no_total[df_no_total['Unicode'] == 'U+02BC']['Percentage Before'].values[0]
    standard_apostrophe_after = df_no_total[df_no_total['Unicode'] == 'U+02BC']['Percentage After'].values[0]

    # Most common apostrophes and their percentages
    top_apostrophes = df_no_total.sort_values(by='Percentage Before', ascending=False).head(2)
    top1_symbol = top_apostrophes.iloc[0]['Unicode']
    top1_percentage = top_apostrophes.iloc[0]['Percentage Before']
    top2_symbol = top_apostrophes.iloc[1]['Unicode']
    top2_percentage = top_apostrophes.iloc[1]['Percentage Before']

    # Symbols that were completely eliminated (changed to 0)
    eliminated_symbols = df_no_total[df_no_total['After Normalization'] == 0]

    # Symbols with minimal remaining presence
    remaining_symbols = df_no_total[(df_no_total['After Normalization'] > 0) &
                                    (df_no_total['Unicode'] != 'U+02BC')]

    # Calculate the conversion to quotation marks (estimate based on difference in totals)
    converted_to_quotes = total_before - total_after
    quotes_percentage = (converted_to_quotes / total_before) * 100

    # Unchanged symbols percentage (based on warnings)
    unchanged_symbols = sum(df_no_total[df_no_total['Unicode'] != 'U+02BC']['After Normalization'])
    unchanged_percentage = (unchanged_symbols / total_after) * 100

    # Print statistics in a format suitable for paper text
    print("Apostrophe Normalization Statistics:")
    print(f"Total apostrophes before normalization: {total_before:,}")
    print(f"Total apostrophes after normalization: {total_after:,}")
    print(f"U+02BC percentage before: {standard_apostrophe_before:.2f}%")
    print(f"U+02BC percentage after: {standard_apostrophe_after:.2f}%")
    print(f"Most common apostrophe symbols: {top1_symbol} ({top1_percentage:.1f}%) and {top2_symbol} ({top2_percentage:.1f}%)")
    print(f"Apostrophes converted to quotation marks: ~{quotes_percentage:.2f}%")
    print(f"Warning count: {warning_count:,} (related to non-standard patterns)")
    print(f"Error count: {error_count:,} (related to ambiguity resolution)")
    print(f"Unchanged apostrophes percentage: {unchanged_percentage:.4f}%")

    # Return the statistics as a dictionary for further use
    return {
        'total_before': total_before,
        'total_after': total_after,
        'standard_before_pct': standard_apostrophe_before,
        'standard_after_pct': standard_apostrophe_after,
        'top1_symbol': top1_symbol,
        'top1_percentage': top1_percentage,
        'top2_symbol': top2_symbol,
        'top2_percentage': top2_percentage,
        'converted_to_quotes_pct': quotes_percentage,
        'warning_count': warning_count,
        'error_count': error_count,
        'unchanged_percentage': unchanged_percentage
    }


df, publication_table = create_apostrophe_results_df(apostrophe_stats_before_normalization, 
                                                   apostrophe_stats_after_apostrophe_normalization)
stats = calculate_apostrophe_statistics(df, warning_apostrophe_count, error_apostrophe_count)

# Stats preview

for key, value in stats.items():
    print(f"{key}: {value}")

publication_table
# Out:
# Apostrophe Normalization Statistics:
# Total apostrophes before normalization: 12,337,416
# Total apostrophes after normalization: 12,310,319
# U+02BC percentage before: 1.17%
# U+02BC percentage after: 99.94%
# Most common apostrophe symbols: U+0027 (60.5%) and U+2019 (38.0%)
# Apostrophes converted to quotation marks: ~0.22%
# Warning count: 7,372 (related to non-standard patterns)
# Error count: 10,733 (related to ambiguity resolution)
# Unchanged apostrophes percentage: 0.0597%
# total_before: 12337416
# total_after: 12310319
# standard_before_pct: 1.1714
# standard_after_pct: 99.9403
# top1_symbol: U+0027
# top1_percentage: 60.5074
# top2_symbol: U+2019
# top2_percentage: 38.0461
# converted_to_quotes_pct: 0.21963270104534044
# warning_count: 7372
# error_count: 10733
# unchanged_percentage: 0.05971413088482923
#   Unicode Symbol  Before Normalization  Percentage Before  \
# 0  U+0027      '               7465048            60.5074
# 5  U+2019      ’               4693904            38.0461
# 3  U+02BC      ʼ                144521             1.1714
# 6  U+0060      `                 20895             0.1694
# 4  U+2018      ‘                 12824             0.1039
# 1  U+02B9      ʹ                   214             0.0017
# 2  U+02BB      ʻ                    10             0.0001
# 0   Total                     12337416           100.0000
#
#    After Normalization  Percentage After
# 0                 5519            0.0448
# 5                 1226            0.0100
# 3             12302968           99.9403
# 6                  397            0.0032
# 4                  209            0.0017
# 1                    0            0.0000
# 2                    0            0.0000
# 0             12310319          100.0000

# %% [markdown]
# # 4.4 Quotation Marks Normalization Results

# %%
import pandas as pd
import unicodedata

# Assuming these variables already contain the count data from your code
# quotation_marks_stats_before_normalization = {...}
# quotation_marks_stats_after_quotation_marks_normalization = {...}
# warning_quotation_mark_count, error_quotation_mark_count = ...

# Define a function to create a readable symbol description
def get_symbol_description(char):
    try:
        name = unicodedata.name(char)
        return f"{char} ({name})"
    except:
        return char

# Create a dataframe for quotation mark statistics
def create_quotation_results_df(before_stats, after_stats):
    # Convert dictionaries to dataframe
    data = []

    for symbol in before_stats.keys():
        before_count = before_stats[symbol]
        after_count = after_stats[symbol]

        # Get unicode code point
        unicode_code = f"U+{ord(symbol):04X}"

        data.append({
            'Unicode': unicode_code,
            'Symbol': symbol,
            'Before Normalization': before_count,
            'After Normalization': after_count
        })

    df = pd.DataFrame(data)

    # Calculate total counts
    total_before = df['Before Normalization'].sum()
    total_after = df['After Normalization'].sum()

    # Add percentage columns
    df['Percentage Before'] = (df['Before Normalization'] / total_before * 100).round(3)
    df['Percentage After'] = (df['After Normalization'] / total_after * 100).round(3)

    # Sort by count before normalization
    df = df.sort_values(by='Before Normalization', ascending=False)

    # Add a row for totals
    totals_row = pd.DataFrame([{
        'Unicode': 'Total',
        'Symbol': '',
        'Before Normalization': total_before,
        'After Normalization': total_after,
        'Percentage Before': 100,
        'Percentage After': 100
    }])

    df = pd.concat([df, totals_row])

    # Reformat the table for readability in publication
    publication_table = df[['Unicode', 'Symbol', 'Before Normalization', 'Percentage Before',
                            'After Normalization', 'Percentage After']]

    return df, publication_table

# Calculate additional statistics for analysis
def calculate_quotation_statistics(df, warning_count, error_count):
    # Exclude the 'Total' row for these calculations
    df_no_total = df[df['Unicode'] != 'Total']

    # Total symbols before normalization
    total_before = df_no_total['Before Normalization'].sum()

    # Total symbols after normalization
    total_after = df_no_total['After Normalization'].sum()

    # Group symbols by type
    guillemets_before = df_no_total[df_no_total['Unicode'].isin(['U+00AB', 'U+00BB'])]['Before Normalization'].sum()
    guillemets_after = df_no_total[df_no_total['Unicode'].isin(['U+00AB', 'U+00BB'])]['After Normalization'].sum()

    curly_quotes_before = df_no_total[df_no_total['Unicode'].isin(['U+201C', 'U+201D'])]['Before Normalization'].sum()
    curly_quotes_after = df_no_total[df_no_total['Unicode'].isin(['U+201C', 'U+201D'])]['After Normalization'].sum()

    straight_quotes_before = df_no_total[df_no_total['Unicode'] == 'U+0022']['Before Normalization'].sum()
    straight_quotes_after = df_no_total[df_no_total['Unicode'] == 'U+0022']['After Normalization'].sum()

    # Calculate percentages
    guillemets_pct_before = (guillemets_before / total_before) * 100
    guillemets_pct_after = (guillemets_after / total_after) * 100

    curly_quotes_pct_before = (curly_quotes_before / total_before) * 100
    curly_quotes_pct_after = (curly_quotes_after / total_after) * 100

    straight_quotes_pct_before = (straight_quotes_before / total_before) * 100
    straight_quotes_pct_after = (straight_quotes_after / total_after) * 100

    # Calculate balance between opening and closing quotes
    opening_guillemets_before = df_no_total[df_no_total['Unicode'] == 'U+00AB']['Before Normalization'].values[0]
    closing_guillemets_before = df_no_total[df_no_total['Unicode'] == 'U+00BB']['Before Normalization'].values[0]

    opening_guillemets_after = df_no_total[df_no_total['Unicode'] == 'U+00AB']['After Normalization'].values[0]
    closing_guillemets_after = df_no_total[df_no_total['Unicode'] == 'U+00BB']['After Normalization'].values[0]

    opening_curly_before = df_no_total[df_no_total['Unicode'] == 'U+201C']['Before Normalization'].values[0]
    closing_curly_before = df_no_total[df_no_total['Unicode'] == 'U+201D']['Before Normalization'].values[0]

    opening_curly_after = df_no_total[df_no_total['Unicode'] == 'U+201C']['After Normalization'].values[0]
    closing_curly_after = df_no_total[df_no_total['Unicode'] == 'U+201D']['After Normalization'].values[0]

    # Calculate balance ratios
    if closing_guillemets_before > 0:
        guillemets_balance_before = abs(opening_guillemets_before / closing_guillemets_before - 1)
    else:
        guillemets_balance_before = float('inf')

    if closing_guillemets_after > 0:
        guillemets_balance_after = abs(opening_guillemets_after / closing_guillemets_after - 1)
    else:
        guillemets_balance_after = float('inf')

    if closing_curly_before > 0:
        curly_balance_before = abs(opening_curly_before / closing_curly_before - 1)
    else:
        curly_balance_before = float('inf')

    if closing_curly_after > 0:
        curly_balance_after = abs(opening_curly_after / closing_curly_after - 1)
    else:
        curly_balance_after = float('inf')

    # Calculate improvement factors
    if guillemets_balance_before > 0 and guillemets_balance_after > 0:
        guillemets_improvement = guillemets_balance_before / guillemets_balance_after
    else:
        guillemets_improvement = float('inf')

    if curly_balance_before > 0 and curly_balance_after > 0:
        curly_improvement = curly_balance_before / curly_balance_after
    else:
        curly_improvement = float('inf')

    # Print statistics in a format suitable for paper text
    print("Quotation Mark Normalization Statistics:")
    print(f"Total quotation marks before normalization: {total_before:,}")
    print(f"Total quotation marks after normalization: {total_after:,}")
    print(f"Straight quotes (U+0022) before: {straight_quotes_pct_before:.2f}%")
    print(f"Guillemets (« ») before: {guillemets_pct_before:.2f}%")
    print(f"Curly quotes (\" \") before: {curly_quotes_pct_before:.2f}%")
    print(f"Straight quotes (U+0022) after: {straight_quotes_pct_after:.2f}%")
    print(f"Guillemets (« ») after: {guillemets_pct_after:.2f}%")
    print(f"Curly quotes (\" \") after: {curly_quotes_pct_after:.2f}%")
    print(f"Guillemets balance improvement: {guillemets_improvement:.2f}x")
    print(f"Curly quotes balance improvement: {curly_improvement:.2f}x")
    print(f"Warning count: {warning_count:,}, {warning_count/total_after*100:.2f}% of total quotes after normalization")
    print(f"Error count: {error_count:,} ({error_count/total_after*100:.2f}% of total quotes after normalization)")

    # Return the statistics as a dictionary for further use
    return {
        'total_before': total_before,
        'total_after': total_after,
        'straight_quotes_pct_before': straight_quotes_pct_before,
        'guillemets_pct_before': guillemets_pct_before,
        'curly_quotes_pct_before': curly_quotes_pct_before,
        'straight_quotes_pct_after': straight_quotes_pct_after,
        'guillemets_pct_after': guillemets_pct_after,
        'curly_quotes_pct_after': curly_quotes_pct_after,
        'guillemets_improvement': guillemets_improvement,
        'curly_improvement': curly_improvement,
        'warning_count': warning_count,
        'warning_percentage': warning_count/total_after*100,
        'error_count': error_count,
        'error_percentage': error_count/total_after*100
    }

# Example usage:
df, publication_table = create_quotation_results_df(quotation_marks_stats_before_normalization, 
                                                  quotation_marks_stats_after_quotation_marks_normalization)
stats = calculate_quotation_statistics(df, warning_quotation_mark_count, error_quotation_mark_count)

# Stats preview
for key, value in stats.items():
    print(f"{key}: {value}")

publication_table
# Out:
# Quotation Mark Normalization Statistics:
# Total quotation marks before normalization: 56,051,936
# Total quotation marks after normalization: 56,076,689
# Straight quotes (U+0022) before: 51.74%
# Guillemets (« ») before: 44.30%
# Curly quotes (" ") before: 3.77%
# Straight quotes (U+0022) after: 0.01%
# Guillemets (« ») after: 95.82%
# Curly quotes (" ") after: 4.16%
# Guillemets balance improvement: 6.40x
# Curly quotes balance improvement: 51.96x
# Warning count: 505,085, 0.90% of total quotes after normalization
# Error count: 351 (0.00% of total quotes after normalization)
# total_before: 56051936
# total_after: 56076689
# straight_quotes_pct_before: 51.74266237655021
# guillemets_pct_before: 44.29581343987833
# curly_quotes_pct_before: 3.7666638312011202
# straight_quotes_pct_after: 0.013873857638064188
# guillemets_pct_after: 95.82446638388369
# curly_quotes_pct_after: 4.161659758478251
# guillemets_improvement: 6.402931671576889
# curly_improvement: 51.95758609453572
# warning_count: 505085
# warning_percentage: 0.9007040340773329
# error_count: 351
# error_percentage: 0.0006259285386838728
#   Unicode Symbol  Before Normalization  Percentage Before  \
# 0  U+0022      "              29002764             51.743
# 1  U+00AB      «              12495485             22.293
# 2  U+00BB      »              12333176             22.003
# 4  U+201D      ”               1065203              1.900
# 3  U+201C      “               1046085              1.866
# 6  U+201E      „                109199              0.195
# 5  U+201F      ‟                    16              0.000
# 7  U+275D      ❝                     4              0.000
# 8  U+275E      ❞                     4              0.000
# 0   Total                     56051936            100.000
#
#    After Normalization  Percentage After
# 0                 7780             0.014
# 1             26895177            47.961
# 2             26840011            47.863
# 4              1166659             2.080
# 3              1167062             2.081
# 6                    0             0.000
# 5                    0             0.000
# 7                    0             0.000
# 8                    0             0.000
# 0             56076689           100.000
